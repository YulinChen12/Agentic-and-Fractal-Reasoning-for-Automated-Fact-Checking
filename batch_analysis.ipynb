# %% [markdown]
# # Unified Article Analysis Model
#
# This notebook integrates all 6 models into a single unified system that takes an article and predicts:
# 1. **News Coverage** - Topic classification
# 2. **Intent** - Communication intent (inform, persuade, entertain, deceive)
# 3. **Sensationalism** - Whether content is sensational or neutral
# 4. **Sentiment** - Emotional sentiment (positive, negative, neutral)
# 5. **Reputation** - Reputation level (low, medium, high)
# 6. **Stance** - Political stance (against, neutral, favor)
# 7. **Title vs. Body** - Checks if the headline's claim accurately reflects the content of the article (e.g., "Agree," "Discuss," "Negate," or "Unrelated").
# 8. **Context Veracity** - Validates the claims within the article against the broader context, checking for consistency and ensuring no contextual shifts alter the meaning.
# 9. **Location / Geography** - Identifies geographic elements in the text and cross-references them to validate the accuracy of the event's location.

# %%
# pip install pandas numpy scikit-learn torch transformers nrclex vaderSentiment
import nltk
nltk.download('punkt_tab')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt_tab to /home/yal149/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /home/yal149/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/yal149/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# Core imports
import pandas as pd
import numpy as np
import re
import csv
import torch
import time
import warnings
warnings.filterwarnings("ignore")

# ML and NLP imports
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.svm import SVC
from scipy.sparse import hstack, csr_matrix
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import normalize, StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.decomposition import LatentDirichletAllocation

# Transformers
from transformers import DistilBertForSequenceClassification, DistilBertTokenizerFast, AutoTokenizer, AutoModelForSequenceClassification
import torch.nn.functional as F

# Sentiment and emotion analysis
from nrclex import NRCLex
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

import os
from google import genai
from google.genai import types
from serpapi import GoogleSearch
import json
import requests
from sentence_transformers import SentenceTransformer
import uuid

print("All imports loaded successfully!")
# Out:
# 2025-12-04 15:01:59.393910: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-12-04 15:01:59.393934: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-12-04 15:01:59.395289: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-04 15:01:59.401887: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# All imports loaded successfully!

# %%
# Data loading and preprocessing functions
COLS = ["id","label","statement","subjects","speaker","job_title",
        "state_info","party_affiliation","barely_true_cnt","false_cnt",
        "half_true_cnt","mostly_true_cnt","pants_on_fire_cnt","context","justification"]

data_path = './data/'

def read_tsv(path):
    """Load TSV data with proper handling of quotes and escape characters"""
    return pd.read_csv(path, sep="\t", header=None, names=COLS,
                       engine="python", quoting=csv.QUOTE_NONE, escapechar="\\",
                       on_bad_lines="skip")

def text_of(r):
    """Combine statement, context, and justification into single text"""
    return " ".join([str(r.get("statement","")), str(r.get("context","")), str(r.get("justification",""))]).strip()

def first_subject(s):
    """Extract first subject from subjects field"""
    parts = re.split(r"[;,]", s) if isinstance(s,str) else []
    return parts[0].strip().lower() if parts and parts[0].strip() else "unknown"

print("Data loading functions defined!")
# Out:
# Data loading functions defined!

# %%
# Model 1: News Coverage Classification
print("Loading News Coverage Model...")

# Load training data
df_tr = read_tsv(data_path + "train2.tsv")
df_va = read_tsv(data_path + "valid.tsv")

X_tr = df_tr.apply(text_of, axis=1)
X_va = df_va.apply(text_of, axis=1)

y_tr = df_tr["subjects"].apply(first_subject)
y_va = df_va["subjects"].apply(first_subject)

keep = y_tr.ne("unknown")
X_tr, y_tr = X_tr[keep], y_tr[keep]

classes = np.unique(y_tr)
weights = compute_class_weight(class_weight="balanced", classes=classes, y=y_tr)
wmap = {c:w for c,w in zip(classes, weights)}

# Train news coverage pipeline
news_coverage_pipe = Pipeline([
    ("tfidf", TfidfVectorizer(lowercase=True, strip_accents="unicode",
                              analyzer="word", ngram_range=(1,2),
                              min_df=2, max_df=0.9, sublinear_tf=True)),
    ("clf", LinearSVC(class_weight=wmap, random_state=42))
])

news_coverage_pipe.fit(X_tr, y_tr)
pred = news_coverage_pipe.predict(X_va)
print(f"News Coverage Model - Accuracy: {accuracy_score(y_va, pred):.4f}")

def predict_news_coverage(text):
    """Predict news coverage topic for given text"""
    prediction = news_coverage_pipe.predict([text])[0]
    return {"topic": str(prediction)}
# Out:
# Loading News Coverage Model...
# News Coverage Model - Accuracy: 0.3279

# %%
# Model 2: Intent Classification
print("Loading Intent Classification Model...")

# Load and prepare data
df = read_tsv(data_path + "train2.tsv")
for c in ["statement","context","justification"]:
    df[c] = df[c].fillna("").astype(str).str.strip()

texts = df.apply(text_of, axis=1).tolist()

# Train TF-IDF vectorizer
intent_tfidf = TfidfVectorizer(
    lowercase=True, strip_accents="unicode",
    analyzer="word", ngram_range=(1,2),
    min_df=3, max_df=0.95, sublinear_tf=True
)
X = intent_tfidf.fit_transform(texts)

# Define prototypes for each intent
PROTOS = {
  "inform":   ["Officials said the department released a report with data and timelines."],
  "persuade": ["We should support this policy because it will improve outcomes."],
  "entertain":["The comedian joked about daily life in a lighthearted, playful tone."],
  "deceive":  ["You won't believe this miracle cure doctors hate; click to see the secret."]
}
CLASS_NAMES = ["inform","persuade","entertain","deceive"]

# Create prototype matrix
proto_rows = []
for name in CLASS_NAMES:
    pv = intent_tfidf.transform(PROTOS[name])
    pv_mean = np.asarray(pv.mean(axis=0))
    pv_norm = normalize(pv_mean, norm="l2", axis=1)
    proto_rows.append(pv_norm.ravel())
PROTO_MAT = np.vstack(proto_rows)

def predict_intent(title="", body=""):
    """Predict intent using prototype matching"""
    text = (" ".join([str(title or ""), str(body or "")])).strip()
    z = intent_tfidf.transform([text])
    zn = normalize(z, norm="l2", axis=1)
    scores = (zn @ PROTO_MAT.T).ravel()
    by_label = {CLASS_NAMES[i]: float(scores[i]) for i in range(4)}
    top_label = max(by_label, key=by_label.get)
    
    return {
        "primary_intent": top_label,
        "confidence_scores": by_label
    }

print("Intent Classification Model loaded!")
# Out:
# Loading Intent Classification Model...
# Intent Classification Model loaded!

# %%
# Model 3: Sensationalism Detection
print("Loading Sensationalism Model...")

TOKEN_RE = re.compile(r"[A-Za-z]+")

EVIDENCE_PATTERNS = [
    r"\b\d{1,3}(?:,\d{3})*(?:\.\d+)?\b",
    r"\b(19|20)\d{2}\b",
    r"%",
    r"https?://",
    r"\"[^\"]+\"",
    r"\baccording to\b",
    r"\breport(ed|s)? by\b|\bstudy\b|\bsurvey\b"
]
EVIDENCE_RE = [re.compile(pat, flags=re.I) for pat in EVIDENCE_PATTERNS]

def evidence_anchors(text):
    s = str(text)
    hits = sum(len(r.findall(s)) for r in EVIDENCE_RE)
    toks = max(1, len(TOKEN_RE.findall(s)))
    dens = np.log1p(hits) / max(10, toks)
    return float(np.clip(dens, 0.0, 0.2))

tfidf = TfidfVectorizer(max_features=3000, stop_words='english', ngram_range=(1,2))
train_text = df_tr['statement'].astype(str) + " " + df_tr['context'].astype(str)

X_train_tfidf = tfidf.fit_transform(train_text)

X_train_ev = df_tr['statement'].apply(evidence_anchors).values.reshape(-1, 1)

X_train_final = hstack([X_train_tfidf, X_train_ev])

SCORE_MAP = {
    "pants-fire": 5, 
    "false": 4, 
    "barely-true": 3, 
    "half-true": 2, 
    "mostly-true": 1, 
    "true": 0
}

# Map labels to scores
train_scores = df_tr['label'].map(SCORE_MAP).fillna(0)

# THRESHOLD = 2.5 means:
# Scores 0, 1, 2 (True, Mostly-True, Half-True) -> 0 (Neutral)
# Scores 3, 4, 5 (Barely-True, False, Pants-Fire) -> 1 (Sensational)
THRESHOLD = 2.5 

y_train_binary = train_scores.apply(lambda x: 1 if x >= THRESHOLD else 0)

rf_model = SVC(kernel="linear", C=0.025, class_weight="balanced", probability=True)
rf_model.fit(X_train_final, y_train_binary)

def _features_for_inference(statement: str, context: str = "") -> np.ndarray:
    # Combine Text (Statement + Context)
    full_text = str(statement) + " " + str(context)
    
    # Vectorize
    tfidf_vec = tfidf.transform([full_text])
    
    # Calculate Evidence Score
    ev_score = evidence_anchors(statement)
    ev_vec = np.array([[ev_score]]) # Reshape to (1, 1) to match sparse matrix format
    
    return hstack([tfidf_vec, ev_vec])

def predict_sensationalism(statement: str, justification: str = ""):
    """
    Predicts if a statement is Sensational/False based on the trained model.
    """
    # Get features
    f_vec = _features_for_inference(statement, justification)
    
    # Predict Probability
    p_sensational = float(rf_model.predict_proba(f_vec)[0, 1])
    
    # Calculate Score (0 to 10)
    # High probability of False = High Sensationalism Score
    score_0_10 = float(np.clip(10.0 * p_sensational, 0.0, 10.0))
    
    # Determine Label
    label = "sensational" if p_sensational >= 0.45 else "neutral"
    
    # Calculate Confidence
    confidence = float(max(p_sensational, 1 - p_sensational))
    
    # Get Evidence Subscore
    evidence_val = float(evidence_anchors(statement))

    return {
        "factor": "sensationalism",
        "score": round(score_0_10, 3),
        "confidence": round(confidence, 3),
        "label": label,
        "subscores": {
            "evidence_density": round(evidence_val, 3),
            "probability_fake": round(p_sensational, 3)
        },
    }

print("Sensationalism Model loaded!")
# Out:
# Loading Sensationalism Model...
# Sensationalism Model loaded!

# %%
# Model 4: Sentiment Analysis
print("Loading Sentiment Analysis Model...")

# Sentiment analysis constants
ALPHA = 1.0
EPS = 1e-8
EMOTIONS_TO_ANALYZE = ["positive", "negative"]
_token_re = re.compile(r"[A-Za-z']+")

def _word_count(text):
    return len(_token_re.findall(str(text)))

def nrc_doc_score_from_text(text, alpha: float = ALPHA):
    emo = NRCLex(str(text))
    pos = emo.raw_emotion_scores.get('positive', 0)
    neg = emo.raw_emotion_scores.get('negative', 0)
    return float(np.log((pos + alpha) / (neg + alpha)))

def get_sentiment_class(vader_row):
    c = float(vader_row.get("compound", 0.0))
    if c >= 0.05:
        return 'Positive'
    elif c <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

class ModelArtifacts:
    def __init__(self, vectorizer, topic_model, topic_mu, topic_sigma):
        self.vectorizer = vectorizer
        self.topic_model = topic_model
        self.topic_mu = topic_mu
        self.topic_sigma = topic_sigma

def train_sentiment_models(train_df, text_col="statement"):
    train_texts = train_df[text_col].fillna("").astype(str).tolist()

    vectorizer = CountVectorizer(max_df=0.9, min_df=5, stop_words='english')
    X_train = vectorizer.fit_transform(train_texts)

    topic_model = LatentDirichletAllocation(n_components=20, random_state=42, learning_method="batch")
    topic_model.fit(X_train)

    theta_train = topic_model.transform(X_train)
    s_train = np.array([nrc_doc_score_from_text(s) for s in train_texts])

    weights_sum = theta_train.sum(axis=0) + EPS
    topic_mu = (theta_train.T @ s_train) / weights_sum

    diffs = s_train[:, None] - topic_mu[None, :]
    topic_var = (theta_train * diffs ** 2).sum(axis=0) / weights_sum
    topic_sigma = np.sqrt(topic_var + EPS)

    return ModelArtifacts(
        vectorizer=vectorizer,
        topic_model=topic_model,
        topic_mu=topic_mu,
        topic_sigma=topic_sigma
    )

def extract_sentiment_features_from_statement(statement: str, artifacts, analyzer) -> dict:
    s = "" if statement is None else str(statement)
    wc = _word_count(s)

    emo_obj = NRCLex(s)
    emo_counts = {e: int(emo_obj.raw_emotion_scores.get(e, 0)) for e in EMOTIONS_TO_ANALYZE}
    emo_densities = {f"{e}_density": (emo_counts[e] / wc) if wc > 0 else 0.0 for e in EMOTIONS_TO_ANALYZE}

    emotion_logratio = float(np.log((emo_counts["positive"] + ALPHA) / (emo_counts["negative"] + ALPHA)))
    s_val = emotion_logratio

    X = artifacts.vectorizer.transform([s])
    theta = artifacts.topic_model.transform(X)

    mu_hat = float((theta @ artifacts.topic_mu)[0])
    var_hat = float((theta @ (artifacts.topic_sigma ** 2))[0] + EPS)
    sd_hat = float(np.sqrt(var_hat))

    sent_dev_diff = float(s_val - mu_hat)
    sent_dev_z = float(sent_dev_diff / sd_hat) if sd_hat > 0 else 0.0

    vader = analyzer.polarity_scores(s)
    sentiment_value = get_sentiment_class(vader)
    sentiment_extremity = abs(float(vader.get("compound", 0.0)))

    return {
        "word_count": wc,
        "emotion_logratio": float(emotion_logratio),
        "sent_dev_diff": float(sent_dev_diff),
        "sent_dev_z": float(sent_dev_z),
        "vader_pos": float(vader.get("pos", 0.0)),
        "vader_neu": float(vader.get("neu", 0.0)),
        "vader_neg": float(vader.get("neg", 0.0)),
        "vader_compound": float(vader.get("compound", 0.0)),
        "sentiment_value": sentiment_value,
        "sentiment_extremity": float(sentiment_extremity),
    }

# Train sentiment model
sentiment_artifacts = train_sentiment_models(df_tr)
vader_analyzer = SentimentIntensityAnalyzer()

def create_sentiment_feature_dataframe(df: pd.DataFrame,
                             artifacts: ModelArtifacts,
                             analyzer: SentimentIntensityAnalyzer,
                             text_col="statement"):

    feature_rows = df[text_col].apply(
        extract_sentiment_features_from_statement,
        args=(artifacts, analyzer)
    )

    features_df = pd.DataFrame(feature_rows.tolist())
    return features_df

train_sentiment_features = create_sentiment_feature_dataframe(df_tr, sentiment_artifacts, vader_analyzer)
validation_sentiment_features = create_sentiment_feature_dataframe(df_va, sentiment_artifacts, vader_analyzer)

features = ["emotion_logratio", 
            "sent_dev_z"
           ]

X_tv = pd.concat([train_sentiment_features[features], validation_sentiment_features[features]], axis=0)
y_tr_sent = train_sentiment_features["sentiment_value"]
y_va_sent = validation_sentiment_features["sentiment_value"]
y_tv = pd.concat([y_tr_sent, y_va_sent], axis=0)

sentiment_pipe = Pipeline(steps=[
    ("scale", StandardScaler(with_mean=False)),
    ("clf", RandomForestClassifier(max_depth=5, n_estimators=10, 
                                   max_features=1, random_state=42))
])

sentiment_pipe.fit(X_tv, y_tv)

def predict_sentiment(statement):
    """Predict sentiment for given statement"""
    feature_dict = extract_sentiment_features_from_statement(statement, sentiment_artifacts, vader_analyzer)
    features_df = pd.DataFrame([feature_dict])
    X_to_predict = features_df[features]
    y_pred = sentiment_pipe.predict(X_to_predict)
    prediction = str(y_pred[0]) 
    return {"sentiment": prediction}

print("Sentiment Analysis Model loaded!")
# Out:
# Loading Sentiment Analysis Model...
# Sentiment Analysis Model loaded!

# %%
# Model 5: Reputation Classification
print("Loading Reputation Model...")

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load reputation model
try:
    reputation_model_path = "./reputation_model"
    reputation_model = DistilBertForSequenceClassification.from_pretrained(reputation_model_path)
    reputation_tokenizer = DistilBertTokenizerFast.from_pretrained(reputation_model_path)
    reputation_model.to(device)
    reputation_model.config.id2label = {0: "low", 1: "medium", 2: "high"}
    reputation_model.config.label2id = {"low": 0, "medium": 1, "high": 2}
    
    # Label encoder for reputation
    rep_encoder = LabelEncoder()
    rep_encoder.fit(["low", "medium", "high"])
    
    print("Reputation Model loaded successfully!")
    
except Exception as e:
    print(f" Reputation model not found: {e}")
    print("Using fallback reputation prediction...")
    
    # Fallback reputation model
    reputation_model = None
    reputation_tokenizer = None
    rep_encoder = None
# Out:
# Loading Reputation Model...
# Using device: cuda
# Reputation Model loaded successfully!

# %%
# Model 6: Stance Classification
print("Loading Stance Model...")

# Ensure imports are available
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

try:
    stance_model_path = "./stance_model"
    stance_tokenizer = AutoTokenizer.from_pretrained(stance_model_path)
    stance_model = AutoModelForSequenceClassification.from_pretrained(stance_model_path)
    stance_model.to(device)
    
    # Stance mapping
    id2stance = {0: "support", 1: "deny", 2: "neutral"}
    
    print(" Stance Model loaded successfully!")
    
except Exception as e:
    print(f" Stance model not found: {e}")
    print("Using fallback stance prediction...")
    
    # Fallback stance model
    stance_model = None
    stance_tokenizer = None
    id2stance = None
# Out:
# Loading Stance Model...
# Using device: cuda
#  Stance Model loaded successfully!

# %%
import nltk
from collections import Counter

def predict_article_reputation(article_text=None, sentences=None):
    """
    Predicts reputation for each sentence and aggregates results with majority vote.
    Can accept either full article text or pre-split sentences.
    """
    # Check if model is loaded
    if reputation_model is None or reputation_tokenizer is None:
        return {"final_label": "medium", "counts": {"medium": 1}}
    
    if sentences is None:
        if article_text is None:
            return {"final_label": "medium", "counts": {"medium": 1}}
        # Split article into sentences if not provided
        sentences = nltk.sent_tokenize(article_text)
        sentences = [s.strip() for s in sentences if s.strip()]
    
    if not sentences:
        return {"final_label": "medium", "counts": {"medium": 1}}

    results = []
    for sent in sentences:
        # Tokenize each sentence separately
        inputs = reputation_tokenizer(
            sent,
            truncation=True,
            padding=True,
            max_length=512,
            return_tensors="pt"
        ).to(device)

        # Forward pass
        with torch.no_grad():
            outputs = reputation_model(**inputs)
            probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
            pred_id = torch.argmax(probs, dim=-1).item()
            label = reputation_model.config.id2label[pred_id]
            score = probs[0][pred_id].item()

        results.append((sent, label, score))

    # --- Majority vote across sentences ---
    labels = [label for _, label, _ in results]
    label_counts = Counter(labels)
    majority_label = label_counts.most_common(1)[0][0]
    return {
        "final_label": majority_label,
        "counts": dict(label_counts),
    }

# %%
def predict_article_stance(article_text=None, sentences=None):
    """
    Predicts stance for each sentence and aggregates results with majority vote.
    Can accept either full article text or pre-split sentences.
    """
    # Check if model is loaded
    if stance_model is None or stance_tokenizer is None:
        return {"final_label": "neutral", "counts": {"neutral": 1}}
    
    if sentences is None:
        if article_text is None:
            return {"final_label": "neutral", "counts": {"neutral": 1}}
        # Split article into sentences if not provided
        sentences = nltk.sent_tokenize(article_text)
        sentences = [s.strip() for s in sentences if s.strip()]
    
    if not sentences:
        return {"final_label": "neutral", "counts": {"neutral": 1}}

    results = []
    for sent in sentences:
        # Tokenize each sentence separately
        inputs = stance_tokenizer(
            sent,
            truncation=True,
            padding=True,
            max_length=512,
            return_tensors="pt"
        ).to(device)

        # Forward pass
        with torch.no_grad():
            outputs = stance_model(**inputs)
            probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
            pred_id = torch.argmax(probs, dim=-1).item()
            label = stance_model.config.id2label[pred_id]
            score = probs[0][pred_id].item()

        results.append((sent, label, score))

    # --- Majority vote across sentences ---
    labels = [label for _, label, _ in results]
    label_counts = Counter(labels)
    majority_label = label_counts.most_common(1)[0][0]

    return {
        "final_label": majority_label,
        "counts": dict(label_counts),
    }

# %%
GOOGLE_API_KEY = "AIzaSyCjRnAJyPKQggEBN9G0ZpNoMzW5ZK-27Bc"
SERPAPI_KEY = "2d4b3d3673b32b0d681d15159b267f4bb4d16fb9129b21b883bebacf62c0a2ca"

client = genai.Client(api_key=GOOGLE_API_KEY)

# %%
def analyze_complete_article(article_title: str = "", article_text: str = "") -> dict:
    """
    Complete article analysis using sentence-level voting from all 6 models.
    """
    results = {
        "predictions": {}
    }

    try:
        sentences = nltk.sent_tokenize(article_text or "")
    except Exception:
        sentences = []

    # Basic cleanup
    sentences = [s.strip() for s in sentences if s.strip()]

    # If NLTK didn't find sentences, fall back to treating the whole text as one "sentence"
    if not sentences and article_text.strip():
        sentences = [article_text.strip()]

    # If still nothing, bail
    if not sentences:
        return {"error": "No valid sentences found to analyze."}

    # Optional length filter (less strict than before)
    sentences = [s for s in sentences if len(s) > 5]
    if not sentences:
        sentences = [article_text.strip()]

    # Initialize counters for voting
    news_coverage_votes = []
    intent_votes = []
    sensationalism_votes = []
    sentiment_votes = []

    # --- Per-sentence models ---
    for sentence in sentences:
        # 1. News Coverage Prediction
        try:
            news_coverage = predict_news_coverage(sentence)["topic"]
            news_coverage_votes.append(news_coverage)
        except Exception:
            pass

        # 2. Intent Prediction
        try:
            intent_result = predict_intent(title="", body=sentence)
            intent_votes.append(intent_result["primary_intent"])
        except Exception:
            pass

        # 3. Sensationalism Prediction
        try:
            sensationalism_result = predict_sensationalism(sentence)
            sensationalism_votes.append(sensationalism_result["label"])
        except Exception:
            pass

        # 4. Sentiment Prediction
        try:
            sentiment = predict_sentiment(sentence)["sentiment"]
            sentiment_votes.append(sentiment)
        except Exception:
            pass

    # 5. Reputation Prediction (uses pre-split sentences)
    try:
        reputation_result = predict_article_reputation(sentences=sentences)
        results["predictions"]["reputation"] = {
            "level": reputation_result["final_label"],
            "model": "DistilBERT (Sentence-level Majority Vote)",
        }
    except Exception as e:
        results["predictions"]["reputation"] = {"error": str(e)}

    # 6. Stance Prediction (uses pre-split sentences)
    try:
        stance_result = predict_article_stance(sentences=sentences)
        results["predictions"]["stance"] = {
            "stance": stance_result["final_label"],
            "model": "AutoModel (Sentence-level Majority Vote)",
        }
    except Exception as e:
        results["predictions"]["stance"] = {"error": str(e)}

    # --- Vote Aggregation for looping models ---

    # News Coverage
    try:
        if news_coverage_votes:
            article_news_coverage = Counter(news_coverage_votes).most_common(1)[0][0]
            results["predictions"]["news_coverage"] = {"topic": article_news_coverage}
        else:
            results["predictions"]["news_coverage"] = {"error": "No votes cast"}
    except Exception:
        results["predictions"]["news_coverage"] = {"error": "Processing error"}

    # Intent
    try:
        if intent_votes:
            article_intent = Counter(intent_votes).most_common(1)[0][0]
            results["predictions"]["intent"] = {"primary_intent": article_intent}
        else:
            results["predictions"]["intent"] = {"error": "No votes cast"}
    except Exception:
        results["predictions"]["intent"] = {"error": "Processing error"}

    # Sensationalism
    try:
        if sensationalism_votes:
            article_sensationalism = Counter(sensationalism_votes).most_common(1)[0][0]
            results["predictions"]["sensationalism"] = {"label": article_sensationalism}
        else:
            results["predictions"]["sensationalism"] = {"error": "No votes cast"}
    except Exception:
        results["predictions"]["sensationalism"] = {"error": "Processing error"}

    # Sentiment
    try:
        if sentiment_votes:
            article_sentiment = Counter(sentiment_votes).most_common(1)[0][0]
            results["predictions"]["sentiment"] = {"sentiment": article_sentiment}
        else:
            results["predictions"]["sentiment"] = {"error": "No votes cast"}
    except Exception:
        results["predictions"]["sentiment"] = {"error": "Processing error"}

    # Return only the predictions dict
    return results["predictions"]

# %%
def serpapi_search(query: str) -> dict:
    """
    Uses SerpAPI to perform a web search and returns a small structured payload
    (titles, links, snippets) that Gemini can reason over.
    """
    print(f"\n[Tool Call] serpapi_search called with query: '{query}'")
    
    # Check if we can perform a real search
    if not SERPAPI_KEY:
        # Return MOCK data if setup is incomplete
        return {
            "results": [
                {"title": f"News regarding {query}", "link": "http://mock-news.com", "snippet": f"This is a simulated search result for {query} because the SerpApi key is missing."},
                {"title": f"Fact Check: {query}", "link": "http://fact-check.org", "snippet": f"Experts discuss the validity of {query} in this simulated snippet."}
            ]
        }

    try:
        params = {
            "engine": "google",
            "q": query,
            "api_key": SERPAPI_KEY,
            "num": 5,
            "hl": "en" # Force language to English
        }
        
        search = GoogleSearch(params)
        results = search.get_dict()
        organic = results.get("organic_results", [])
        clean_results = []
        
        for r in organic:
            clean_results.append({
                "title": r.get("title"),
                "link": r.get("link"),
                "snippet": r.get("snippet"),
                "date": r.get("date", "Unknown")
            })

        return {"results": clean_results}

    except Exception as e:
        return {"error": f"Search failed: {str(e)}", "results": []}

# %%
tools_mixed = [analyze_complete_article, serpapi_search]
tools_predictive_only = [analyze_complete_article] # Normal & CoT No Search: Predictive Function Only

system_instruction = (
    "You are a news-analysis assistant. "
    "You must obey the user’s instructions about phases and output format. "
    "Always use the available tools when appropriate. "
    "Do not output raw tool JSON in your final answer."
)

PROMPT_CONFIGS = {
    "normal": types.GenerateContentConfig(
        tools=tools_predictive_only,
        temperature=0.1,
        system_instruction=system_instruction,
        tool_config=types.ToolConfig(
            function_calling_config=types.FunctionCallingConfig(mode="AUTO")
        ),
    ),
    "cot_google": types.GenerateContentConfig(
        tools=tools_mixed,
        temperature=0.1,
        system_instruction=system_instruction,
        tool_config=types.ToolConfig(
            function_calling_config=types.FunctionCallingConfig(mode="AUTO")
        ),
    ),
    "cot_no_search": types.GenerateContentConfig(
        tools=tools_predictive_only,
        temperature=0.1,
        system_instruction=system_instruction,
        tool_config=types.ToolConfig(
            function_calling_config=types.FunctionCallingConfig(mode="AUTO")
        ),
    ),
}

# %%
prompt_normal_google = """
You are a senior investigative editor at an independent fact-checking newsroom.
You are mentoring a junior analyst and must produce a clear, concise fact-check report for each article.

Your goal is to provide a hybrid analysis by first calling predictive tools and then giving short, well-justified labels.
Keep explanations for each factor brief (around 3-5 sentences). Do NOT describe every intermediate thought process.

**FEW-SHOT EXAMPLES (GROUND TRUTH):**
{few_shot_examples}

**CALIBRATION INSTRUCTION (CRITICAL):**
The examples above represent the **Gold Standard** for this task.
1. **Analyze the patterns:** Observe how the human annotators defined "Sensationalism," "Stance," and "News Topic" in the examples above.
2. **Mimic the Logic:** You must calibrate your internal thresholds to match these examples.
   - Example: If the human labels a slightly critical text as "Neutral," you must also label similar texts as "Neutral."
   - Example: If the human labels a specific source as "High Reputation," align your judgment with that standard.
3. **Prioritize Precedent:** Your final labels must be consistent with the decision boundaries established in the Ground Truth examples provided above.

**Here is the article:**

---
{article_to_analyze}
---

In this setting, you have **NO access to web search or external knowledge**.
You can only use:
1. `analyze_complete_article` – runs 6 predictive models and returns model scores.

**STRICT EXECUTION PROTOCOL (Follow Order):**

1.  **GATHER DATA FIRST:**
    * Call `analyze_complete_article` immediately.
    * Review the article for specific claims.
    * **CRITICAL:** Do NOT start writing the final report yet. Just collect your tool outputs.

2.  **GENERATE REPORT SECOND:**
    * **ONLY** after you have received all tool outputs, generate the **COMPLETE** Markdown dashboard below.

---

## Phase 1: Model Predictions
**CRITICAL INSTRUCTION: STRICT TRANSCRIPTION ONLY**
- In this section, you are a **mechanical transcriber**.
* **Action:** You MUST call `analyze_complete_article` immediately using the article's title and body.
* **Wait:** Do not proceed to Phase 2 until you receive the JSON output from this tool.
- You must output the **EXACT** label provided by the `analyze_complete_article` tool.
- **DO NOT** correct, interpret, or change the tool's labels, even if you think they are wrong.

**Required Output List:**
  1. news_topic
  2. intent
  3. sensationalism
  4. sentiment
  5. reputation
  6. stance
  
- Do NOT show raw JSON.

---

## Phase 2: Qualitative Analysis (Generative Reasoning, NO EXTERNAL SEARCH)

Take the model scores into account, but do not blindly trust them.
If you disagree with a label, state your alternative and briefly explain why.

---

**Output Format Requirements:**

Your final response MUST be a clean Markdown dashboard with the following two main sections:

## Phase 1: Model Predictions
- Only show factor → prediction pairs derived from the tool output.
- Do NOT include any raw JSON code blocks.

## Phase 2: Qualitative Analysis
- Follow the factor-by-factor structure below.
- Use natural language Markdown, not JSON.
- Keep each **Reasoning** section to around 3-5 sentences.

---

**CONFIDENCE SCORE RUBRIC (0–100%):**

Because you have no external data, all judgments must be based on the article and the model outputs.

**TRACK A: For "Context Veracity" & "Location / Geography" (Internal-Evidence-Based)**

* **90–100%:** The article is highly detailed, internally consistent, and reads like serious reporting; very few red flags.
* **75–89%:** Generally coherent with minor gaps or vague areas.
* **50–74%:** Mixed signals; some details seem plausible but others are vague or odd.
* **25–49%:** Many red flags, vague language, or manipulative framing; trust is low.
* **0–24%:** Extremely implausible or internally contradictory; you suspect very low veracity.

**TRACK B: For News Topic, Stance, Title vs. Body & Sensationalism (Analysis-Based)**

* **90–100%:** Very clear and explicit language supporting your label.
* **75–89%:** Overall direction is clear, with some nuance.
* **50–74%:** Mixed or ambiguous signals.
* **25–49%:** Very short or vague text; mostly guessing.
* **0–24%:** You cannot meaningfully determine a label.

Always report confidence as an **integer percentage** between 0 and 100.

---

Now apply this structure:

**1. News Topic**
* **Output:** [Your Label]
* **Confidence:** [0–100]%
* **Reasoning:** [around 3-5 sentences]

**2. Sensationalism**
* **Output:** [sensational or neutral]
* **Confidence:** [0–100]%
* **Reasoning:** [around 3-5 sentences]

**3. Stance**
* **Output:** [support, deny, or neutral]
* **Confidence:** [0–100]%
* **Reasoning:** [around 3-5 sentences]

**4. Title vs. Body**
* **Output:** ["Agree", "Discuss", "Negate", "Unrelated"]
* **Confidence:** [0–100]%
* **Reasoning:** [around 3-5 sentences]

**5. Context Veracity (NO EXTERNAL SEARCH)**
* **Output:** [Accurate, Inaccurate, Misleading, Unverified]
* **Confidence:** [0–100]%
* **Reasoning:** [around 3-5 sentences]

**6. Location / Geography (NO EXTERNAL SEARCH)**
* **Output:** [e.g., "Global," "US-centric," "Specific (e.g., Seattle, WA)"]
* **Confidence:** [0–100]%
* **Reasoning:** [around 3-5 sentences]

Start by calling the `analyze_complete_article` function.

---

IMPORTANT FINAL OUTPUT RULES (READ CAREFULLY):

- In your FINAL answer, you MUST:
  1. Start with the exact heading: `## Phase 1: Model Predictions`
  2. Then include the exact heading: `## Phase 2: Qualitative Analysis`
  3. Under **Phase 2**, you MUST provide ALL SIX sections in this order:
     1. News Topic
     2. Sensationalism
     3. Stance
     4. Title vs. Body
     5. Context Veracity
     6. Location / Geography

- You MUST fill out ALL six sections.
- Do NOT output anything labeled `tool_code`, `thought`, or similar meta sections.
- Do NOT output any intermediate reasoning steps or planning; only the final analysis.
- Do NOT restate or quote the instructions or “recipes”.
- Output ONLY the final Markdown dashboard described above.
"""

# %%
prompt_cot_google = """
You are a senior investigative editor at an independent fact-checking newsroom.
You are mentoring a junior analyst and must produce a rigorous, transparent fact-check report for each article.

**FEW-SHOT EXAMPLES (GROUND TRUTH):**
{few_shot_examples}

**CALIBRATION INSTRUCTION (CRITICAL):**
The examples above represent the **Gold Standard** for this task.
1. **Analyze the patterns:** Observe how the human annotators defined "Sensationalism," "Stance," and "News Topic" in the examples above.
2. **Mimic the Logic:** You must calibrate your internal thresholds to match these examples.
   - Example: If the human labels a slightly critical text as "Neutral," you must also label similar texts as "Neutral."
   - Example: If the human labels a specific source as "High Reputation," align your judgment with that standard.
3. **Prioritize Precedent:** Your final labels must be consistent with the decision boundaries established in the Ground Truth examples provided above.

Your goal is to provide a hybrid analysis.

**Here is the article:**

---
{article_to_analyze}
---

**You have access to two tools:**
1. `analyze_complete_article` – runs predictive models.
2. `serpapi_search` – performs web search to verify claims.

**STRICT EXECUTION PROTOCOL (Follow Order):**

1.  **GATHER DATA FIRST:**
    * Call `analyze_complete_article` immediately.
    * Review the article for specific claims and call `serpapi_search` to verify facts, dates, or events.
    * **CRITICAL:** Do NOT start writing the final report yet. Just collect your tool outputs.

2.  **GENERATE REPORT SECOND:**
    * **ONLY** after you have received all tool outputs, generate the **COMPLETE** Markdown dashboard below.

---

**Output Format Requirements:**

Your final response MUST be a clean Markdown dashboard with the following two main sections:

## Phase 1: Model Predictions
**CRITICAL INSTRUCTION: STRICT TRANSCRIPTION ONLY**
- In this section, you are a **mechanical transcriber**.
* **Action:** You MUST call `analyze_complete_article` immediately using the article's title and body.
* **Wait:** Do not proceed to Phase 2 until you receive the JSON output from this tool.
- You must output the **EXACT** label provided by the `analyze_complete_article` tool.
- **DO NOT** correct, interpret, or change the tool's labels, even if you think they are wrong.

**Required Output List:**
  1. news_topic
  2. intent
  3. sensationalism
  4. sentiment
  5. reputation
  6. stance
  
- Do NOT show raw JSON.

## Phase 2: Qualitative Analysis
- Follow the factor-by-factor structure below.
- You MUST provide ALL SIX sections in this order:
     1. News Topic
     2. Sensationalism
     3. Stance
     4. Title vs. Body
     5. Context Veracity
     6. Location / Geography

---

**CONFIDENCE SCORE RUBRIC (0–100%):**

**TRACK A: For "Context Veracity" & "Location" (Evidence-Based)**
* **90–100%:** Direct, quote-level evidence from search explicitly confirms the claim.
* **75–89%:** Strong supporting evidence found, but minor details differ.
* **50–74%:** Related context found, but no direct confirmation.
* **25–49%:** No strong evidence; weak or conflicting.
* **0–24%:** Evidence strongly contradicts the article.

**TRACK B: For Topic, Stance, Title vs. Body & Sensationalism (Analysis-Based)**
* **90–100%:** Explicit, unambiguous language supports your label.
* **75–89%:** Trend is clear and consistent.
* **50–74%:** Text is mixed, ambiguous, or open to interpretation.
* **25–49%:** Text is too short or vague.
* **0–24%:** Cannot meaningfully determine.

---

**Analysis Sections (Include these in your final output):**

**1. News Topic**
* Recipe: What kind of news is covered in this article? Determine the type of news: local, global, opinion, etc. Check if similar events receive similar coverage. Compare coverage angle with other reputable sources.
* **Output:** [Label]
* **Confidence:** [0–100]%
* **Reasoning:** [Brief explanation]

**2. Sensationalism**
* Recipe: Is the text using sensationalist words and phrases designed to attract attention or manipulate? Examine text for overly dramatic or exaggerated claims. Compare the emotional tone of the headline vs. the content.
* **Output:** [sensational or neutral]
* **Confidence:** [0–100]%
* **Reasoning:** [Brief explanation]

**3. Stance**
* Recipe: What is the author's opinion about the news? Analyze if content supports, denies, or is neutral towards claims. Evaluate consistency in stance throughout the content. Determine if shifts in stance are supported by factual developments.
* **Output:** [support, deny, or neutral]
* **Confidence:** [0–100]%
* **Reasoning:** [Brief explanation]

**4. Title vs. Body**
* Recipe: Analyze the relationship between the title and the body text: "Does the title agree with, discuss, is unrelated to, or negate the body of the text?" First, identify the main claim of the title. Second, summarize the main arguments of the full article text. Third, explain your verdict.
* **Output:** ["Agree", "Discuss", "Negate", "Unrelated"]
* **Confidence:** [0–100]%
* **Reasoning:** [Brief explanation]

**5. Context Veracity (Cite your search results here)**
* Recipe: Evaluate truthfulness on two levels: 1) Internal Check for consistency, 2) External Verification using `serpapi_search` to verify core claims. Synthesis: Weigh internal logic against external evidence.
* **Output:** [Accurate, Inaccurate, Misleading, Unverified]
* **Confidence:** [0–100]%
* **Reasoning:**
    * **Internal:** Check for consistency.
    * **External:** Explicitly cite what you found using `serpapi_search`.

**6. Location / Geography (Cite your search results here)**
* Recipe: Where is the text about? What are the geographic elements? Validate the accuracy of geographic details using `serpapi_search`.
* **Output:** [e.g., "Global," "US-centric," "Specific"]
* **Confidence:** [0–100]%
* **Reasoning:** Validate geographic details.

---

Start by calling `analyze_complete_article`.
"""

# %%
prompt_cot_no_search = """
You are a senior investigative editor at an independent fact-checking newsroom.
You are mentoring a junior analyst and must produce a rigorous, transparent fact-check report for each article.

In this setting, you have **NO access to web search or external knowledge**.
You can only use:
1. `analyze_complete_article` – runs 6 predictive models and returns model scores.

Your goal is to provide a hybrid analysis by first calling the predictive tool and then performing your own generative reasoning based solely on the article and the model outputs.

**FEW-SHOT EXAMPLES (GROUND TRUTH):**
{few_shot_examples}

**CALIBRATION INSTRUCTION (CRITICAL):**
The examples above represent the **Gold Standard** for this task.
1. **Analyze the patterns:** Observe how the human annotators defined "Sensationalism," "Stance," and "News Topic" in the examples above.
2. **Mimic the Logic:** You must calibrate your internal thresholds to match these examples.
   - Example: If the human labels a slightly critical text as "Neutral," you must also label similar texts as "Neutral."
   - Example: If the human labels a specific source as "High Reputation," align your judgment with that standard.
3. **Prioritize Precedent:** Your final labels must be consistent with the decision boundaries established in the Ground Truth examples provided above.

**Here is the article:**

---
{article_to_analyze}
---

**Your Task (Perform in this order):**

Always start with `analyze_complete_article` (Phase 1). In Phase 2, you must reason **without** web search or any external tools.

---

## Phase 1: Model Predictions
**CRITICAL INSTRUCTION: STRICT TRANSCRIPTION ONLY**
- In this section, you are a **mechanical transcriber**.
* **Action:** You MUST call `analyze_complete_article` immediately using the article's title and body.
* **Wait:** Do not proceed to Phase 2 until you receive the JSON output from this tool.
- You must output the **EXACT** label provided by the `analyze_complete_article` tool.
- **DO NOT** correct, interpret, or change the tool's labels, even if you think they are wrong.

**Required Output List:**
  1. news_topic
  2. intent
  3. sensationalism
  4. sentiment
  5. reputation
  6. stance
  
- Do NOT show raw JSON.

---

**Phase 2: Qualitative Analysis (Generative Reasoning, NO EXTERNAL SEARCH)**

You will receive the predictive model scores. Take these labels into account as only one input among many.
Do NOT over-rely on them. Assess the article independently. If you disagree with the labels, explain why.

You must evaluate **Context Veracity** and **Location** using only:
- Internal consistency,
- Level of detail,
- Plausibility signals in the writing style and content.

You may mention what kinds of external sources you *would* check in a real system, but do NOT assume their results here and do NOT call any search tools.

---

**Output Format Requirements:**

Your final response MUST be a clean Markdown dashboard with the following two main sections:

## Phase 1: Model Predictions

- Only show factor → prediction pairs derived from the tool output.
- Do NOT include any raw JSON code blocks.

## Phase 2: Qualitative Analysis

- Follow the factor-by-factor structure below.
- Use natural language Markdown, not JSON.

---

**CONFIDENCE SCORE RUBRIC (0–100%):**

Because you have no external data, all judgments must be based on the article and the model outputs.

**TRACK A: For "Context Veracity" & "Location / Geography" (Internal-Evidence-Based)**

* **90–100%:** The article is highly detailed, internally consistent, and reads like serious reporting; very few red flags.
* **75–89%:** Generally coherent with minor gaps or vague areas.
* **50–74%:** Mixed signals; some details seem plausible but others are vague or odd.
* **25–49%:** Many red flags, vague language, or manipulative framing; trust is low.
* **0–24%:** Extremely implausible or internally contradictory; you suspect very low veracity.

**TRACK B: For News Topic, Stance, Title vs. Body & Sensationalism (Analysis-Based)**

* **90–100%:** Very clear and explicit language supporting your label.
* **75–89%:** Overall direction is clear, with some nuance.
* **50–74%:** Mixed or ambiguous signals.
* **25–49%:** Very short or vague text; mostly guessing.
* **0–24%:** You cannot meaningfully determine a label.

Always report confidence as an **integer percentage** between 0 and 100.

---

Review the article again and provide the following, including your reasoning for each:

---

**1. News Topic**

* Recipe: What kind of news is covered in this article? Determine the type of news: local, global, opinion, etc. 
You cannot look anything up; base your judgment only on the text and the model predictions.

* **Output:** [Your Label]
* **Confidence:** [0–100]%
* **Reasoning:** [Your Reasoning]

---

**2. Sensationalism**

* Recipe: Is the text using sensationalist words and phrases designed to attract attention or manipulate? 
Examine text for overly dramatic or exaggerated claims. Compare the emotional tone of the headline vs. the content.
Determine if content uses shock value over facts.

* **Output:** [sensational or neutral]
* **Confidence:** [0–100]%
* **Reasoning:** [Your Reasoning]

---

**3. Stance**

* Recipe: What is the author's opinion about the news? Analyze if content supports, denies, or is neutral towards claims. Evaluate consistency in stance throughout the content.
Determine if shifts in stance are supported by factual developments.

* **Output:** [support, deny, or neutral]
* **Confidence:** [0–100]%
* **Reasoning:** [Your Reasoning]

---

**4. Title vs. Body**

* Recipe: Analyze the relationship between the title and the body text: "Does the title agree with, discuss, is unrelated to, or negate the body of the text?" 
First, identify the main claim of the title. Second, summarize the main arguments of the full article text. 
Third, explain your verdict based on whether the text supports, contradicts, just discusses, or is unrelated to the title's claim.

* **Output:** ["Agree", "Discuss", "Negate", "Unrelated"]
* **Confidence:** [0–100]%
* **Reasoning:** [Your narrative explanation, referencing the recipe.]

---

**5. Context Veracity (NO EXTERNAL SEARCH)**

* Recipe: Evaluate the article's truthfulness based only on internal evidence.

    1.  **Internal Check:** Examine the text for contextual shifts, logical inconsistencies, or missing key details.
    2.  **Plausibility:** Consider whether the story sounds realistic given the level of detail and style of writing.
    3.  **Synthesis:** Weigh these signals to decide whether the context seems High, Medium, Low, or Inconsistent in veracity.

* **Output:** [Accurate, Inaccurate, Misleading, Unverified]
* **Confidence:** [0–100]%
* **Reasoning:** Explain your judgment using only internal cues.

---

**6. Location / Geography (NO EXTERNAL SEARCH)**

* Recipe: Where is the text about? What are the geographic elements connected to it? 
Identify any explicit locations, regions, or countries mentioned. Judge whether the article focuses on a specific place, on the US, or on global issues, based only on the text.

* **Output:** [e.g., "Global," "US-centric," "Specific (e.g., Seattle, WA)"]
* **Confidence:** [0–100]%
* **Reasoning:** Explain your judgment using only the locations and geographic cues mentioned in the article.

---

Start by calling the `analyze_complete_article` function.

---

IMPORTANT FINAL OUTPUT RULES (READ CAREFULLY):

- In your FINAL answer, you MUST:
  1. Start with the exact heading: `## Phase 1: Model Predictions`
  2. Then include the exact heading: `## Phase 2: Qualitative Analysis`
  3. Under **Phase 2**, you MUST provide ALL SIX sections in this order:
     1. News Topic
     2. Sensationalism
     3. Stance
     4. Title vs. Body
     5. Context Veracity
     6. Location / Geography

- You MUST fill out ALL six sections.
- Do NOT output anything labeled `tool_code`, `thought`, or similar meta sections.
- Do NOT output any intermediate reasoning steps or planning; only the final analysis.
- Do NOT restate or quote the instructions or “recipes”.
- Output ONLY the final Markdown dashboard described above.
"""

# %%
PROMPT_TEMPLATES = {
    "normal": prompt_normal_google,
    "cot_no_search": prompt_cot_no_search,
    "cot_google": prompt_cot_google,
}

# %%
TRAIN_FILE_PATH = "./data/train_article.json"
TEST_FILE_PATH  = "./data/test_article.json"
OUTPUT_FILE     = "batch_analysis_results.json"

# %%
# LOAD JSON DATA
def load_data(path):
    print(f"Loading data from: {path}")
    if not os.path.exists(path):
        raise FileNotFoundError(f"File not found: {path}")
        
    with open(path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    if isinstance(data, dict) and "articles" in data:
        return data["articles"]
    elif isinstance(data, list):
        return data
    else:
        raise ValueError(f"Unknown JSON structure in {path}")

# FORMAT TRAIN EXAMPLES
def format_few_shot_context(articles):
    """
    Formats the 7 training articles into a prompt string.
    """
    output_text = "Here are reference examples of human-verified analysis:\n\n"
    
    for art in articles:
        # --- Inputs --- 
        headline = art.get('headline', 'No Title')
        body = art.get('text', 'No Text')
        source = art.get('news_source', 'Unknown Source')
        author = art.get('author', 'Unknown Author')
        
        # --- GROUND TRUTH --- 
        topic = art.get('coverage', 'N/A')
        intent = art.get('intent', 'N/A')
        sensationalism = art.get('sensationalism', 'N/A')
        sentiment = art.get('sentiment', 'N/A')
        reputation = art.get('reputation', 'N/A')
        stance = art.get('stance', 'N/A')
        title_vs_body = art.get('title_vs_body', 'N/A')
        veracity = art.get('context_veracity', 'N/A')
        location = art.get('location', 'N/A')
        
        # --- INPUT BLOCK ---
        output_text += f"--- EXAMPLE INPUT ---\n"
        output_text += f"Source: {source}\n"
        output_text += f"Author: {author}\n"
        output_text += f"Title: {headline}\n"
        output_text += f"Body: {body}\n\n"
        
        # --- OUTPUT BLOCK ---
        output_text += f"--- EXAMPLE HUMAN LABELING OUTPUT ---\n"
        output_text += f"- news_topic: {topic}\n"
        output_text += f"- intent: {intent}\n"
        output_text += f"- sensationalism: {sensationalism}\n"
        output_text += f"- sentiment: {sentiment}\n"
        output_text += f"- reputation: {reputation}\n"
        output_text += f"- stance: {stance}\n"
        output_text += f"- title_vs_body: {title_vs_body}\n"
        output_text += f"- context_veracity: {veracity}\n"
        output_text += f"- location: {location}\n\n"
        
    return output_text

# %%
# --- HELPER: RATE LIMIT HANDLER ---
def safe_generate_content(client, model, contents, config, retries=3):
    """
    Wraps the API call with a retry mechanism for 429 errors.
    """
    for attempt in range(retries):
        try:
            return client.models.generate_content(
                model=model,
                contents=contents,
                config=config,
            )
        except Exception as e:
            # Check if the error string contains "429" (Rate Limit Exceeded)
            if "429" in str(e):
                wait_time = (attempt + 1) * 20  # Backoff: 20s, 40s, 60s
                print(f"\n[Warning] Rate limit hit. Retrying in {wait_time}s...")
                time.sleep(wait_time)
            else:
                raise e  # If it's not a rate limit error, crash immediately
    
    raise Exception(f"Max retries ({retries}) exceeded for API call.")


# --- MAIN EXECUTION ---
def run_batch_analysis(mode, max_articles=None, max_iterations=3):
    
    # Validation
    if mode not in PROMPT_CONFIGS:
        raise ValueError(f"CRITICAL ERROR: Mode '{mode}' is not defined in PROMPT_CONFIGS.")
    config = PROMPT_CONFIGS[mode]
    
    if mode not in PROMPT_TEMPLATES:
        raise ValueError(f"CRITICAL ERROR: Mode '{mode}' is not defined in PROMPT_TEMPLATES.")
    template_string = PROMPT_TEMPLATES[mode]

    # Load Data
    train_articles = load_data(TRAIN_FILE_PATH)
    test_articles = load_data(TEST_FILE_PATH)
    
    if max_articles:
        print(f"Limiting to first {max_articles} articles.")
        test_articles = test_articles[:max_articles]
    
    print(f"Loaded {len(train_articles)} Training Articles.")
    print(f"Processing {len(test_articles)} Test Articles.")

    few_shot_string = format_few_shot_context(train_articles)
    results_data = []

    print(f"--- Starting Batch Run (Mode: {mode}) ---")
    
    for idx, article in enumerate(test_articles):
        headline = article.get("headline", "No Title")
        body = article.get("text", "")
        source = article.get('news_source', 'Unknown Source')
        author = article.get('author', 'Unknown Author')
        a_id = article.get("article_id", f"test_{idx}")
        
        print(f"\n=== ARTICLE: '{headline}' ===")
        print(f"\n>>> Running mode: {mode}")
        
        # Prepare Prompt
        article_content = (
            f"Source: {source}\n"
            f"Author: {author}\n"
            f"Title: {headline}\n"
            f"Body: {body}"
        )
        
        final_prompt = template_string.format(
            few_shot_examples=few_shot_string,
            article_to_analyze=article_content
        )

        for i in range(max_iterations):
            max_retries = 3
            response = None
            
            for attempt in range(max_retries):
                try:
                    chat = client.chats.create(
                        model="gemini-2.5-flash",
                        config=config
                    )
                    
                    response = chat.send_message(final_prompt)
                    break
                    
                except Exception as e:
                    if "429" in str(e):
                        wait_time = (attempt + 1) * 20
                        print(f"\n[Warning] Rate limit hit. Retrying in {wait_time}s...")
                        time.sleep(wait_time)
                    else:
                        print(f"Error on attempt {attempt+1}: {e}")
            
            # CHECK IF RESPONSE WAS OBTAINED
            if response is None:
                print("Error: Max retries exceeded or fatal error.")
                results_data.append({
                    "article_id": a_id,
                    "iteration": i+1,
                    "mode": mode,
                    "error": "Max retries exceeded"
                })
                continue

            try:
                if not response.candidates or not response.candidates[0].content.parts:
                    safety_feedback = getattr(response, 'prompt_feedback', 'No feedback')
                    print(f"ERROR: Response blocked. Safety feedback: {safety_feedback}")
                    results_data.append({
                        "article_id": a_id,
                        "iteration": i+1,
                        "mode": mode,
                        "error": f"BLOCKED: {safety_feedback}"
                    })
                    continue 
                
                print(response.text)
                print("-" * 80)
                
                results_data.append({
                    "article_id": a_id,
                    "iteration": i+1,
                    "mode": mode,
                    "output": response.text,
                    "human_labels": {
                        "coverage": article.get("coverage"),
                        "intent": article.get("intent"),
                        "sensationalism": article.get("sensationalism"),
                        "sentiment": article.get("sentiment"),
                        "reputation": article.get("reputation"),
                        "stance": article.get("stance"),
                        "title_vs_body": article.get("title_vs_body"),
                        "context_veracity": article.get("context_veracity"),
                        "location": article.get("location"),
                    }
                })
                
                time.sleep(5) 
                
            except Exception as e:
                print(f"Error processing response: {e}")
                results_data.append({
                    "article_id": a_id,
                    "iteration": i+1,
                    "mode": mode,
                    "error": str(e)
                })

    # Save Results
    with open(OUTPUT_FILE, 'w', encoding='utf-8') as f:
        json.dump(results_data, f, indent=2)
    print(f"\nSaved results to {OUTPUT_FILE}")

# %%
run_batch_analysis(mode="cot_google", max_articles=20)
# Out:
# Loading data from: ./data/train_article.json
# Loading data from: ./data/test_article.json
# Limiting to first 20 articles.
# Loaded 7 Training Articles.
# Processing 20 Test Articles.
# --- Starting Batch Run (Mode: cot_google) ---
#
# === ARTICLE: 'Trump’s push to end Ukraine war raises fears of 'ugly deal' for Europe' ===
#
# >>> Running mode: cot_google
#
# [Tool Call] serpapi_search called with query: 'U.S. Special Envoy Steve Witkoff Russia Putin'
#
# [Tool Call] serpapi_search called with query: 'German Defence Minister Boris Pistorius "which alliances we will still be able to trust in future and which ones will be durable"'
#
# [Tool Call] serpapi_search called with query: 'Marco Rubio U.S. Secretary of State'
#
# [Tool Call] serpapi_search called with query: 'Secretary of State Marco Rubio skipping NATO foreign ministers meeting Brussels'
#
# [Tool Call] serpapi_search called with query: 'German Foreign Minister Johann Wadephul "Russia is at least keeping open the option of war against NATO – by 2029 at the latest"'
#
# [Tool Call] serpapi_search called with query: 'Europe aid to Ukraine 180 billion euros since February 2022'
#
# [Tool Call] serpapi_search called with query: 'EU leaders 140 billion euro loan Ukraine frozen Russian assets'
# ## Phase 1: Model Predictions
# - news_topic: foreign-policy
# - intent: inform
# - sensationalism: neutral
# - sentiment: Positive
# - reputation: low
# - stance: support
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# * **Output:** Foreign Policy
# * **Confidence:** 95%
# * **Reasoning:** The article focuses on international relations, specifically the geopolitical implications of a potential peace deal in the Ukraine war, the role of NATO, and the concerns of European nations regarding their security and alliances.
#
# **2. Sensationalism**
# * **Output:** Neutral
# * **Confidence:** 90%
# * **Reasoning:** The language used in the article is analytical and reports on concerns and fears, but it does so in a factual manner without employing overly dramatic or exaggerated claims. Quotes about an "ugly deal" are attributed to an expert, not presented as the article's own sensationalized statement.
#
# **3. Stance**
# * **Output:** Critical
# * **Confidence:** 80%
# * **Reasoning:** The article consistently highlights European fears, risks, and limited influence regarding a potential peace deal that might not align with their interests, particularly concerning Russia. This focus on negative implications for Europe indicates a critical stance towards the potential outcomes of such a deal.
#
# **4. Title vs. Body**
# * **Output:** Agree
# * **Confidence:** 95%
# * **Reasoning:** The title, "Trump’s push to end Ukraine war raises fears of 'ugly deal' for Europe," accurately reflects the main theme of the article. The body elaborates on these fears by detailing the specific concerns of European nations regarding Russia, territorial concessions, and their limited leverage in the peace process.
#
# **5. Context Veracity**
# * **Output:** Reasonably accurate
# * **Confidence:** 85%
# * **Reasoning:**
#     *   **Internal:** The article maintains a consistent narrative regarding European concerns about a potential peace deal.
#     *   **External:**
#         *   The existence of U.S. Special Envoy Steve Witkoff and his meeting with Russian President Vladimir Putin on Tuesday is confirmed by search results.
#         *   German Defence Minister Boris Pistorius's quote about trust in alliances is confirmed by search results.
#         *   Marco Rubio's role as U.S. Secretary of State and his plan to skip a NATO foreign ministers meeting in Brussels are confirmed by search results.
#         *   German Foreign Minister Johann Wadephul's quote about Russia's war option against NATO by 2029 is confirmed by search results.
#         *   The figure of "180 billion euros in aid to Ukraine" is reported by Reuters and other news outlets, but a single, consolidated official source for this exact cumulative figure from all European sources is not immediately found in search results, though it is a widely cited figure in news.
#         *   The claim that EU leaders have not agreed on using frozen Russian assets to fund a 140-billion-euro loan to Ukraine is confirmed by search results, indicating ongoing discussions and some rejections of the plan.
#
# **6. Location / Geography**
# * **Output:** Global
# * **Confidence:** 95%
# * **Reasoning:** The article's scope is international, focusing on the war in Ukraine, its impact on Europe, the involvement of the United States and Russia, and the dynamics of the NATO alliance. Specific locations mentioned include Brussels, Ukraine, and Russia.
# --------------------------------------------------------------------------------
#
# [Tool Call] serpapi_search called with query: 'U.S. Special Envoy Steve Witkoff Russia Putin'
#
# [Tool Call] serpapi_search called with query: 'current U.S. Secretary of State'
#
# [Tool Call] serpapi_search called with query: 'Boris Pistorius German Defence Minister statement alliances'
#
# [Tool Call] serpapi_search called with query: 'Johann Wadephul German Foreign Minister Russia NATO 2029'
#
# [Tool Call] serpapi_search called with query: 'Europe aid to Ukraine 180 billion euros'
#
# [Tool Call] serpapi_search called with query: 'EU 140 billion euro loan to Ukraine frozen Russian assets'
# ## Phase 1: Model Predictions
#
# *   news_topic: foreign-policy
# *   intent: inform
# *   sensationalism: neutral
# *   sentiment: Positive
# *   reputation: low
# *   stance: support
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# *   **Output:** Foreign Policy
# *   **Confidence:** 95%
# *   **Reasoning:** The article explicitly discusses international relations, specifically focusing on the war in Ukraine, NATO, U.S.-Europe relations, and Russia's geopolitical actions.
#
# **2. Sensationalism**
# *   **Output:** Neutral
# *   **Confidence:** 90%
# *   **Reasoning:** The language used is factual and analytical, reporting on fears and concerns of European officials without employing overly dramatic or exaggerated terms. While the topic is serious, the tone remains measured.
#
# **3. Stance**
# *   **Output:** Neutral
# *   **Confidence:** 75%
# *   **Reasoning:** The article reports on the fears and concerns of European officials regarding a potential peace deal in Ukraine and its implications for European security. It presents these concerns as a factual report of their perspective, rather than explicitly supporting or denying the claims made by Trump or the European officials. The model's output of "support" seems to be an overinterpretation of reporting on concerns. My analysis aligns with a neutral stance, as it objectively presents different viewpoints and potential outcomes without taking a side.
#
# **4. Title vs. Body**
# *   **Output:** Agree
# *   **Confidence:** 95%
# *   **Reasoning:** The title, "Trump’s push to end Ukraine war raises fears of 'ugly deal' for Europe," directly reflects the main theme of the article, which details European anxieties about a potential peace settlement that might not serve their interests or weaken Russia sufficiently.
#
# **5. Context Veracity**
# *   **Output:** Accurate
# *   **Confidence:** 90%
# *   **Reasoning:**
#     *   **Internal:** The article maintains a consistent narrative, presenting European concerns and official statements without internal contradictions.
#     *   **External:**
#         *   `serpapi_search(query = "U.S. Special Envoy Steve Witkoff Russia Putin")` confirmed that Steve Witkoff is a U.S. Special Envoy and recently met with Vladimir Putin.
#         *   `serpapi_search(query = "current U.S. Secretary of State")` confirmed Marco Rubio is the current U.S. Secretary of State (effective Jan 21, 2025), making the statement about his involvement plausible in the article's forward-looking context.
#         *   `serpapi_search(query = "Boris Pistorius German Defence Minister statement alliances")` confirmed that Boris Pistorius is the German Defence Minister and made statements regarding shifting alliances.
#         *   `serpapi_search(query = "Johann Wadephul German Foreign Minister Russia NATO 2029")` confirmed that Johann Wadephul is the German Foreign Minister and made the statement about Russia potentially attacking NATO by 2029.
#         *   `serpapi_search(query = "Europe aid to Ukraine 180 billion euros")` found multiple sources, including Reuters, confirming that Europe has provided around 180 billion euros in aid to Ukraine.
#         *   `serpapi_search(query = "EU 140 billion euro loan to Ukraine frozen Russian assets")` showed that the EU is indeed discussing and unveiling plans for a loan to Ukraine using frozen Russian assets, with figures around €165 billion, making the 140 billion euro figure and the lack of full agreement plausible.
#
# **6. Location / Geography**
# *   **Output:** Global
# *   **Confidence:** 95%
# *   **Reasoning:** The article is primarily focused on the geopolitical implications of the Ukraine war, involving the United States, Europe (specifically Brussels, Germany), Russia, and Ukraine. It discusses global security and alliances.
# --------------------------------------------------------------------------------
#
# [Tool Call] serpapi_search called with query: 'U.S. Special Envoy Steve Witkoff Russia Putin'
#
# [Tool Call] serpapi_search called with query: 'current U.S. Secretary of State'
#
# [Tool Call] serpapi_search called with query: 'Boris Pistorius German Defence Minister statement alliances'
#
# [Tool Call] serpapi_search called with query: 'Johann Wadephul German Foreign Minister Russia NATO 2029'
#
# [Tool Call] serpapi_search called with query: 'Europe aid to Ukraine 180 billion euros since February 2022'
#
# [Tool Call] serpapi_search called with query: 'EU frozen Russian assets 140 billion euro loan Ukraine'
# ## Phase 1: Model Predictions
#
# *   news_topic: foreign-policy
# *   intent: inform
# *   sensationalism: neutral
# *   sentiment: Positive
# *   reputation: low
# *   stance: support
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# *   **Output:** Foreign Policy
# *   **Confidence:** 95%
# *   **Reasoning:** The article primarily discusses international relations, geopolitical strategies, and the war in Ukraine, involving major global actors like the US, Russia, and European nations.
#
# **2. Sensationalism**
# *   **Output:** Neutral
# *   **Confidence:** 90%
# *   **Reasoning:** The language used is factual and analytical, reporting on concerns and political discussions without employing overly dramatic or exaggerated claims. While the topic is serious, the tone remains objective.
#
# **3. Stance**
# *   **Output:** Neutral
# *   **Confidence:** 75%
# *   **Reasoning:** The article reports on European fears and concerns regarding a potential peace deal in Ukraine, presenting their perspective. It doesn't explicitly support or deny the claims made by any single party but rather reports on the differing viewpoints and potential outcomes. The model's "support" stance seems to be an overinterpretation of reporting on European concerns. The article is reporting *on* the fears, not necessarily supporting a particular outcome.
#
# **4. Title vs. Body**
# *   **Output:** Agree
# *   **Confidence:** 95%
# *   **Reasoning:** The title "Trump’s push to end Ukraine war raises fears of 'ugly deal' for Europe" accurately reflects the main theme of the body, which details European anxieties about a potential peace settlement that might not favor their interests or weaken Russia sufficiently.
#
# **5. Context Veracity**
# *   **Output:** Reasonably accurate
# *   **Confidence:** 75%
# *   **Reasoning:**
#     *   **Internal:** The article maintains internal consistency in its narrative about European concerns regarding a potential peace deal.
#     *   **External:**
#         *   **Steve Witkoff's visit to Putin:** `serpapi_search` confirms that Steve Witkoff is a U.S. Special Envoy and met with Vladimir Putin recently, aligning with the article's claim.
#         *   **Marco Rubio as U.S. Secretary of State:** `serpapi_search` indicates Marco Rubio's incumbency as Secretary of State begins January 21, 2025. The article is dated December 2, implying it's reporting on a future administration or a hypothetical scenario. While the individual and role are correct for a future context, attributing a statement to him *as* Secretary of State in December is anachronistic for the present date of the article, making this specific detail misleading in its immediate context.
#         *   **Boris Pistorius's statement:** `serpapi_search` confirms Boris Pistorius is the German Defence Minister and made statements consistent with the quote about shifting alliances.
#         *   **Johann Wadephul's statement:** `serpapi_search` confirms Johann Wadephul is the German Foreign Minister and made the statement about Russia potentially attacking NATO by 2029.
#         *   **Europe's aid to Ukraine (180 billion euros):** The article itself is a search result, confirming the figure within the article. However, other official EU sources found via `serpapi_search` provide different, smaller figures for direct EU aid. This suggests the 180 billion euro figure might be a broader aggregation of aid from various European sources (individual countries, different types of aid) rather than solely direct EU budget contributions. Given Reuters' reputation, it's likely a broadly accurate aggregate, but specific breakdowns are not immediately confirmed by other official sources.
#         *   **Frozen Russian assets and 140-billion-euro loan:** `serpapi_search` confirms ongoing discussions about using frozen Russian assets to fund Ukraine, with proposals around €165 billion, and that agreement has not yet been reached, aligning with the article's claims.
#
# **6. Location / Geography**
# *   **Output:** Global
# *   **Confidence:** 95%
# *   **Reasoning:** The article discusses events and concerns spanning multiple countries and regions, including Ukraine, Russia, Europe (Brussels, Germany, France, Britain), and the United States (Washington, Florida), making it a global news story.
# --------------------------------------------------------------------------------
#
# === ARTICLE: 'Hong Kong orders judge-led probe into fire that killed 151' ===
#
# >>> Running mode: cot_google
#
# [Tool Call] serpapi_search called with query: 'Hong Kong fire December 2 151 deaths judge-led probe'
#
# [Tool Call] serpapi_search called with query: 'Hong Kong Wang Fuk Court fire arrests residents concerns'
#
# [Tool Call] serpapi_search called with query: 'Hong Kong fire vigils Tokyo Taipei London'
# ## Phase 1: Model Predictions
# - news_topic: crime
# - intent: inform
# - sensationalism: neutral
# - sentiment: Neutral
# - reputation: low
# - stance: neutral
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# * **Output:** Foreign Policy / Local News
# * **Confidence:** 85%
# * **Reasoning:** The article primarily focuses on a significant local tragedy in Hong Kong, including the government's response, investigation, and local community impact. However, it also touches upon international aspects with vigils in other cities and international rights groups' comments, giving it a secondary foreign policy dimension. Given the primary focus on a domestic event and its immediate aftermath, "Local News" is a strong fit, but the broader implications and international attention also lean towards "Foreign Policy" in a broader sense of governance and human rights.
#
# **2. Sensationalism**
# * **Output:** Neutral
# * **Confidence:** 90%
# * **Reasoning:** The article reports on a tragic event with a high death toll but uses factual and descriptive language without resorting to overly dramatic or exaggerated claims. The tone is informative and objective, focusing on the details of the investigation, arrests, and community impact.
#
# **3. Stance**
# * **Output:** Neutral
# * **Confidence:** 90%
# * **Reasoning:** The article presents information about the fire, the government's response, the investigation, and public reactions in a balanced manner. It reports on arrests, resident concerns, and international rights groups' comments without explicitly endorsing or condemning any particular viewpoint.
#
# **4. Title vs. Body**
# * **Output:** Agree
# * **Confidence:** 95%
# * **Reasoning:** The title "Hong Kong orders judge-led probe into fire that killed 151" accurately reflects the central theme and key facts presented in the body of the article. The body elaborates on the probe, the death toll, and related details, directly supporting the title's claim.
#
# **5. Context Veracity (Cite your search results here)**
# * **Output:** Accurate
# * **Confidence:** 90%
# * **Reasoning:**
#     *   **Internal:** The article maintains internal consistency, with details about the fire, investigation, and community response flowing logically.
#     *   **External:** `serpapi_search` results confirm the core claims:
#         *   A major fire occurred in Hong Kong (Wang Fuk Court) with a high death toll (around 151-156).
#         *   Hong Kong's leader, John Lee, ordered a judge-led probe into the fire.
#         *   The fire occurred around November 26, with the probe announcement on a Tuesday (consistent with the article's Dec 2 report date).
#         *   Residents of Wang Fuk Court had indeed raised prior concerns about fire hazards.
#         *   Arrests were made in connection with the fire and its aftermath, including for suspected manslaughter and related to criticism.
#         *   Vigils were planned or due to take place in Tokyo, Taipei, and London.
#
# **6. Location / Geography (Cite your search results here)**
# * **Output:** Specific
# * **Confidence:** 95%
# * **Reasoning:** The article is specifically about an event in Hong Kong, with mentions of Wang Fuk Court as the location of the fire. It also references other specific cities (Tokyo, Taipei, London) where vigils were held. `serpapi_search` confirmed these geographic details.
# --------------------------------------------------------------------------------
#
# [Tool Call] serpapi_search called with query: 'Hong Kong fire 151 killed judge-led probe'
#
# [Tool Call] serpapi_search called with query: 'Hong Kong fire arrests manslaughter corruption'
#
# [Tool Call] serpapi_search called with query: 'Wang Fuk Court Hong Kong fire hazards concerns'
#
# [Tool Call] serpapi_search called with query: 'Hong Kong fire vigils Tokyo Taipei London'
# ## Phase 1: Model Predictions
#
# *   news_topic: crime
# *   intent: inform
# *   sensationalism: neutral
# *   sentiment: Neutral
# *   reputation: low
# *   stance: neutral
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# *   **Output:** Crime
# *   **Confidence:** 95%
# *   **Reasoning:** The article details a deadly fire, subsequent arrests for manslaughter and corruption, and an official investigation, all of which are central to the topic of crime and its aftermath.
#
# **2. Sensationalism**
# *   **Output:** Neutral
# *   **Confidence:** 90%
# *   **Reasoning:** The language used is factual and reports on a tragic event without employing sensationalist vocabulary or emotional appeals.
#
# **3. Stance**
# *   **Output:** Neutral
# *   **Confidence:** 90%
# *   **Reasoning:** The article objectively reports on the events, investigations, and various reactions without taking a discernible side or expressing a strong opinion.
#
# **4. Title vs. Body**
# *   **Output:** Agree
# *   **Confidence:** 95%
# *   **Reasoning:** The title directly states the core event and the government's response, which is thoroughly elaborated and supported by the content of the article.
#
# **5. Context Veracity (Cite your search results here)**
# *   **Output:** Accurate
# *   **Confidence:** 90%
# *   **Reasoning:**
#     *   **Internal:** The article maintains internal consistency, presenting a coherent narrative of the fire, its investigation, and related events.
#     *   **External:**
#         *   A `serpapi_search` for "Hong Kong fire 151 killed judge-led probe" confirmed a major fire in Hong Kong, a judge-led inquiry, and a high number of casualties (151 or 156), aligning with the article's core claim.
#         *   A `serpapi_search` for "Hong Kong fire arrests manslaughter corruption" confirmed arrests for suspected manslaughter and a related corruption probe. While the exact numbers of individuals arrested varied slightly across search results, the central claim of arrests and a corruption investigation is verified.
#         *   A `serpapi_search` for "Wang Fuk Court Hong Kong fire hazards concerns" strongly corroborated the article's claim that residents of Wang Fuk Court had previously raised concerns about fire hazards.
#         *   A `serpapi_search` for "Hong Kong fire vigils Tokyo Taipei London" confirmed that vigils were planned or had taken place in these cities, supporting the article's statement.
#
# **6. Location / Geography (Cite your search results here)**
# *   **Output:** Specific (Hong Kong, with international mentions)
# *   **Confidence:** 95%
# *   **Reasoning:** The primary geographic focus of the article is Hong Kong, where the deadly fire occurred and the subsequent investigation is underway. Mentions of Tokyo, Taipei, and London are in the context of vigils held in response to the Hong Kong tragedy, reinforcing Hong Kong as the central location.
# --------------------------------------------------------------------------------
#
# [Tool Call] serpapi_search called with query: 'Hong Kong fire December 2 151 deaths judge-led probe'
#
# [Tool Call] serpapi_search called with query: 'Hong Kong Wang Fuk Court fire arrests resident concerns vigils'
# ## Phase 1: Model Predictions
#
# *   **news_topic**: crime
# *   **intent**: inform
# *   **sensationalism**: neutral
# *   **sentiment**: Neutral
# *   **reputation**: low
# *   **stance**: neutral
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# *   **Output**: Foreign Policy / Disaster
# *   **Confidence**: 90%
# *   **Reasoning**: The article primarily focuses on a major disaster in Hong Kong, its investigation, and the government's response, which falls under disaster news. The mention of international vigils and international rights groups also gives it a foreign policy dimension.
#
# **2. Sensationalism**
# *   **Output**: Neutral
# *   **Confidence**: 90%
# *   **Reasoning**: The article reports on a tragic event but uses factual and objective language without overly dramatic or exaggerated claims. The tone is informative and somber, reflecting the gravity of the situation.
#
# **3. Stance**
# *   **Output**: Neutral
# *   **Confidence**: 90%
# *   **Reasoning**: The article presents information about the fire, the investigation, and various reactions (civic groups, police, international rights groups) without explicitly taking a side or expressing a strong opinion. It reports on different perspectives.
#
# **4. Title vs. Body**
# *   **Output**: Agree
# *   **Confidence**: 95%
# *   **Reasoning**: The title "Hong Kong orders judge-led probe into fire that killed 151" accurately reflects the main subject of the article, which details the investigation ordered by Hong Kong's leader into the deadly fire and its aftermath.
#
# **5. Context Veracity (Cite your search results here)**
# *   **Output**: Accurate
# *   **Confidence**: 90%
# *   **Reasoning**:
#     *   **Internal**: The article maintains internal consistency, with details about the fire, investigation, and resident concerns flowing logically.
#     *   **External**: `serpapi_search` results confirm the core claims:
#         *   A major fire occurred in Hong Kong, and the leader ordered a judge-led committee to investigate, as reported on December 2nd. (Source: Al Jazeera, FRANCE24, CBS19News)
#         *   The death toll of 151 is consistently reported across multiple news sources. (Source: Al Jazeera, CBS19News)
#         *   Police arrested 13 people for suspected manslaughter. (Source: Reuters, The Guardian)
#         *   The fire occurred at Wang Fuk Court, and residents had previously raised concerns about fire hazards. (Source: Reuters, Human Rights Watch, Asahi Shimbun)
#         *   While specific vigils in Tokyo, Taipei, and London were not explicitly confirmed by search, the widespread impact and calls for accountability make such events plausible.
#
# **6. Location / Geography (Cite your search results here)**
# *   **Output**: Specific
# *   **Confidence**: 95%
# *   **Reasoning**: The article is specifically about an event in Hong Kong. While it mentions vigils in other cities (Tokyo, Taipei, London), the primary focus and all core events are centered in Hong Kong. `serpapi_search` confirms the event's location in Hong Kong.
# --------------------------------------------------------------------------------
#
# === ARTICLE: 'Prison guard says Luigi Mangione, alleged CEO killer, spoke of 3D-printed gun' ===
#
# >>> Running mode: cot_google
#
# [Tool Call] serpapi_search called with query: 'Luigi Mangione UnitedHealthcare CEO Brian Thompson'
#
# [Tool Call] serpapi_search called with query: 'Luigi Mangione 3D-printed gun backpack'
#
# [Tool Call] serpapi_search called with query: 'Luigi Mangione McDonald's 911 Pennsylvania'
#
# [Tool Call] serpapi_search called with query: 'Luigi Mangione terrorism charges trial date'
# ## Phase 1: Model Predictions
#
# -   **news_topic**: guns
# -   **intent**: entertain
# -   **sensationalism**: neutral
# -   **sentiment**: Neutral
# -   **reputation**: medium
# -   **stance**: deny
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# *   **Output:** Crime / Legal
# *   **Confidence:** 95%
# *   **Reasoning:** The article primarily covers a murder case, including details about the arrest, court testimony, evidence, and legal proceedings, which firmly places it within the crime and legal news domain.
#
# **2. Sensationalism**
# *   **Output:** Neutral
# *   **Confidence:** 90%
# *   **Reasoning:** The article reports on the ongoing court case in a factual and objective manner. It avoids dramatic language, exaggerated claims, or emotional appeals, focusing instead on presenting the details of the testimony and legal arguments.
#
# **3. Stance**
# *   **Output:** Neutral
# *   **Confidence:** 80%
# *   **Reasoning:** The article presents information from both the prosecution (prison guard testimony, evidence found) and the defense (arguments about unlawful search and Miranda warnings). It reports on the legal process and the differing claims without endorsing one side over the other, maintaining a neutral stance.
#
# **4. Title vs. Body**
# *   **Output:** Agree
# *   **Confidence:** 95%
# *   **Reasoning:** The title, "Prison guard says Luigi Mangione, alleged CEO killer, spoke of 3D-printed gun," accurately reflects a central piece of information detailed in the article's body, which discusses the guard's testimony and the discovery of the 3D-printed weapon.
#
# **5. Context Veracity (Cite your search results here)**
# *   **Output:** Accurate
# *   **Confidence:** 95%
# *   **Reasoning:**
#     *   **Internal:** The article maintains internal consistency, presenting a coherent narrative of the legal proceedings against Luigi Mangione.
#     *   **External:** Web searches confirm the core claims:
#         *   `serpapi_search(query = "Luigi Mangione UnitedHealthcare CEO Brian Thompson")` confirmed Luigi Mangione is accused of killing UnitedHealthcare CEO Brian Thompson and was arrested around December 2024.
#         *   `serpapi_search(query = "Luigi Mangione 3D-printed gun backpack")` confirmed that a 3D-printed gun and other items in a backpack are central to the case.
#         *   `serpapi_search(query = "Luigi Mangione McDonald's 911 Pennsylvania")` confirmed a 911 call from a McDonald's manager in Pennsylvania led to the arrest and that body camera footage related to the police interaction was played in court.
#         *   `serpapi_search(query = "Luigi Mangione terrorism charges trial date")` confirmed that terrorism charges were dismissed in September and that trial dates have not yet been set.
#
# **6. Location / Geography (Cite your search results here)**
# *   **Output:** United States
# *   **Confidence:** 95%
# *   **Reasoning:** The article explicitly mentions "NEW YORK" as the location of the court proceedings and a "Pennsylvania McDonald's" where the 911 call originated and the arrest occurred, clearly situating the events within the United States.
# --------------------------------------------------------------------------------
#
# [Tool Call] serpapi_search called with query: 'Luigi Mangione UnitedHealthcare CEO Brian Thompson'
#
# [Tool Call] serpapi_search called with query: 'Luigi Mangione arrest date 3D printed gun backpack'
#
# [Warning] Rate limit hit. Retrying in 20s...
#
# [Tool Call] serpapi_search called with query: 'Luigi Mangione UnitedHealthcare CEO Brian Thompson'
#
# [Tool Call] serpapi_search called with query: 'Luigi Mangione 3D-printed gun backpack terrorism charges dismissed'
# ## Phase 1: Model Predictions
# - news_topic: guns
# - intent: entertain
# - sensationalism: neutral
# - sentiment: Neutral
# - reputation: medium
# - stance: deny
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# * **Output:** Crime / Legal
# * **Confidence:** 95%
# * **Reasoning:** The article details a criminal case involving an alleged murder, court testimony, and legal proceedings, which squarely places it in the crime and legal news category.
#
# **2. Sensationalism**
# * **Output:** Neutral
# * **Confidence:** 90%
# * **Reasoning:** The article reports on court testimony and legal arguments using factual and objective language. There is no evidence of overly dramatic phrasing or exaggerated claims, maintaining a neutral tone despite the serious subject matter.
#
# **3. Stance**
# * **Output:** Neutral
# * **Confidence:** 85%
# * **Reasoning:** The article presents information from both the prosecution (guard testimony, items found) and the defense (unlawful search, improper questioning) without favoring either side. It reports on the legal proceedings objectively.
#
# **4. Title vs. Body**
# * **Output:** Agree
# * **Confidence:** 95%
# * **Reasoning:** The title, "Prison guard says Luigi Mangione, alleged CEO killer, spoke of 3D-printed gun," directly reflects the primary focus of the article's body, which elaborates on the guard's testimony regarding Mangione's statements about the weapon and the ongoing legal case.
#
# **5. Context Veracity (Cite your search results here)**
# * **Output:** Accurate
# * **Confidence:** 95%
# * **Reasoning:**
#     *   **Internal:** The article maintains internal consistency in its narrative of the events and legal proceedings.
#     *   **External:** `serpapi_search` results confirm that Luigi Mangione is indeed accused of killing UnitedHealthcare CEO Brian Thompson (Source: Wikipedia, PBS NewsHour, The Guardian). The search also confirmed the involvement of a 3D-printed gun and the dismissal of terrorism charges (Source: Reuters, CNN, CBS News). The location of the arrest at a Pennsylvania McDonald's was also corroborated (Source: The Guardian). The article's mention of the arrest in December 2024 is consistent with current news reports from December 2025 discussing the ongoing legal proceedings for an event that occurred approximately a year prior.
#
# **6. Location / Geography (Cite your search results here)**
# * **Output:** US-centric
# * **Confidence:** 95%
# * **Reasoning:** The article explicitly mentions "NEW YORK" as the location of the court proceedings and a "Pennsylvania McDonald's" as the site of Mangione's arrest. These specific references confirm the events are centered within the United States.
# --------------------------------------------------------------------------------
#
# [Tool Call] serpapi_search called with query: 'Luigi Mangione UnitedHealthcare CEO Brian Thompson'
#
# [Tool Call] serpapi_search called with query: 'Luigi Mangione backpack contents 3D-printed gun journal'
#
# [Tool Call] serpapi_search called with query: 'Luigi Mangione McDonald's surveillance footage arrest'
#
# [Tool Call] serpapi_search called with query: 'Luigi Mangione terrorism charges dismissed'
#
# [Tool Call] serpapi_search called with query: 'Luigi Mangione trial dates'
# ## Phase 1: Model Predictions
# - news_topic: guns
# - intent: entertain
# - sensationalism: neutral
# - sentiment: Neutral
# - reputation: medium
# - stance: deny
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# * **Output:** Crime / Legal
# * **Confidence:** 95%
# * **Reasoning:** The article focuses on a murder case, court testimony, and legal proceedings, which clearly falls under crime and legal news.
#
# **2. Sensationalism**
# * **Output:** Neutral
# * **Confidence:** 90%
# * **Reasoning:** The article reports on court proceedings in a factual and objective manner, without using overly dramatic language or exaggerated claims. It sticks to reporting testimony and legal developments.
#
# **3. Stance**
# * **Output:** Neutral
# * **Confidence:** 85%
# * **Reasoning:** The article presents information from both the prosecution (prison guard testimony, evidence found) and the defense (unlawful search, improper questioning). It reports on the legal arguments without taking a side, maintaining a neutral stance.
#
# **4. Title vs. Body**
# * **Output:** Agree
# * **Confidence:** 95%
# * **Reasoning:** The title states that a prison guard said Luigi Mangione spoke of a 3D-printed gun. The body of the article directly discusses this testimony, the context of the arrest, and the legal arguments surrounding the evidence, fully aligning with the title's claim.
#
# **5. Context Veracity (Cite your search results here)**
# * **Output:** Accurate
# * **Confidence:** 90%
# * **Reasoning:**
#     *   **Internal:** The article is internally consistent, presenting a coherent narrative of the court proceedings.
#     *   **External:** External searches confirm the core facts: Luigi Mangione is accused of killing UnitedHealthcare CEO Brian Thompson, he was arrested in December 2024, a 3D-printed gun was a key piece of evidence, his arrest involved a Pennsylvania McDonald's and surveillance footage, and terrorism charges were indeed dismissed. Trial dates are also reported as not yet set, aligning with ongoing pre-trial hearings.
#         *   `serpapi_search(query = "Luigi Mangione UnitedHealthcare CEO Brian Thompson")` confirmed the identities and the alleged crime.
#         *   `serpapi_search(query = "Luigi Mangione backpack contents 3D-printed gun journal")` and `serpapi_search(query = "Luigi Mangione McDonald\'s surveillance footage arrest")` supported the details about the 3D-printed gun, backpack, McDonald's arrest, and surveillance footage.
#         *   `serpapi_search(query = "Luigi Mangione terrorism charges dismissed")` confirmed the dismissal of terrorism charges.
#         *   `serpapi_search(query = "Luigi Mangione trial dates")` indicated ongoing pre-trial activities, consistent with trial dates not being set.
#
# **6. Location / Geography (Cite your search results here)**
# * **Output:** US-centric
# * **Confidence:** 95%
# * **Reasoning:** The article explicitly mentions New York (for the court proceedings and the alleged murder) and Pennsylvania (for the McDonald's arrest and 911 call). All events and legal actions described are situated within the United States.
#     *   `serpapi_search(query = "Luigi Mangione UnitedHealthcare CEO Brian Thompson")` and `serpapi_search(query = "Luigi Mangione McDonald\'s surveillance footage arrest")` results consistently place the events and legal proceedings in the US (New York, Pennsylvania).
# --------------------------------------------------------------------------------
#
# === ARTICLE: 'As Putin and Witkoff prepare to meet, White House is 'very optimistic'' ===
#
# >>> Running mode: cot_google
#
# [Tool Call] serpapi_search called with query: 'current US Secretary of State'
#
# [Tool Call] serpapi_search called with query: 'current White House Press Secretary'
#
# [Tool Call] serpapi_search called with query: 'Steve Witkoff special envoy Russia Ukraine'
#
# [Tool Call] serpapi_search called with query: 'Jared Kushner Marco Rubio Ukraine peace talks'
#
# [Tool Call] serpapi_search called with query: 'Putin recent statements Ukraine negotiations'
#
# [Tool Call] serpapi_search called with query: 'Zelenskyy recent meetings Macron Dublin'
# ## Phase 1: Model Predictions
#
# *   news_topic: foreign-policy
# *   intent: inform
# *   sensationalism: neutral
# *   sentiment: Positive
# *   reputation: low
# *   stance: deny
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# *   **Output:** Foreign Policy
# *   **Confidence:** 95%
# *   **Reasoning:** The article explicitly discusses international diplomacy, peace negotiations between the US, Russia, and Ukraine, and the roles of various world leaders and envoys in these efforts. This clearly falls under the domain of foreign policy.
#
# **2. Sensationalism**
# *   **Output:** Neutral
# *   **Confidence:** 90%
# *   **Reasoning:** The language used in the article is factual and reports on diplomatic efforts without employing overly dramatic or exaggerated claims. While the White House is described as "very optimistic," this is presented as a direct quote rather than an editorialized exaggeration.
#
# **3. Stance**
# *   **Output:** Neutral
# *   **Confidence:** 75%
# *   **Reasoning:** The article reports on the ongoing diplomatic efforts from multiple perspectives (US, Russia, Ukraine) without overtly favoring one side or expressing a strong opinion on the likelihood of success. It presents both optimistic views from the White House and Putin's hardline stance. The model's "deny" stance seems to be an anomaly here, as the article is reporting on events rather than denying a specific claim. Based on the content, a neutral stance is more appropriate.
#
# **4. Title vs. Body**
# *   **Output:** Agree
# *   **Confidence:** 90%
# *   **Reasoning:** The title, "As Putin and Witkoff prepare to meet, White House is 'very optimistic'," accurately reflects the central theme of the article, which details the upcoming meeting and the White House's hopeful outlook regarding peace negotiations. The body elaborates on these points.
#
# **5. Context Veracity**
# *   **Output:** Misleading
# *   **Confidence:** 25%
# *   **Reasoning:**
#     *   **Internal:** The article maintains internal consistency regarding the roles of Steve Witkoff, Jared Kushner, Marco Rubio as Secretary of State, and Karoline Leavitt as White House Press Secretary within its narrative.
#     *   **External:** External verification reveals significant discrepancies with current real-world facts. While Steve Witkoff and Jared Kushner have been involved in discussions related to Ukraine, the article presents Marco Rubio as the Secretary of State and Karoline Leavitt as the White House Press Secretary, both of whom are not the current officeholders in the real world (as of late 2024). The search results indicate these individuals would hold these positions in January 2025, suggesting the article is set in a hypothetical future or is entirely fabricated. Other claims, such as Putin's statements and Zelenskyy's recent travels, align with search results for a hypothetical December 2025 timeframe. However, the fundamental misrepresentation of current government officials makes the overall context misleading for a reader expecting a factual news report about present events.
#
# **6. Location / Geography**
# *   **Output:** Global
# *   **Confidence:** 90%
# *   **Reasoning:** The article discusses events and diplomatic efforts spanning multiple international locations, including London, Moscow, Florida (USA), Paris (France), Dublin (Ireland), and references to Ukraine and Russia. This indicates a global geographic scope.
# --------------------------------------------------------------------------------
#
# [Tool Call] serpapi_search called with query: 'Steve Witkoff meeting Vladimir Putin Moscow'
#
# [Tool Call] serpapi_search called with query: 'Jared Kushner Marco Rubio Ukraine peace talks Witkoff'
#
# [Tool Call] serpapi_search called with query: 'White House Press Secretary Karoline Leavitt'
#
# [Tool Call] serpapi_search called with query: 'Putin Ukraine withdraw territories negotiations pointless'
#
# [Tool Call] serpapi_search called with query: 'Putin Russian forces captured two contested Ukrainian cities'
#
# [Tool Call] serpapi_search called with query: 'Zelenskyy met Macron Paris Dublin diplomatic talks'
# ## Phase 1: Model Predictions
# - news_topic: foreign-policy
# - intent: inform
# - sensationalism: neutral
# - sentiment: Positive
# - reputation: low
# - stance: deny
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# * **Output:** Foreign Policy
# * **Confidence:** 95%
# * **Reasoning:** The article primarily discusses international diplomacy, peace negotiations, and the ongoing conflict between Russia and Ukraine, which are all central themes of foreign policy.
#
# **2. Sensationalism**
# * **Output:** Neutral
# * **Confidence:** 90%
# * **Reasoning:** The article uses factual language to report on diplomatic efforts and statements from various officials. There is no overly dramatic or exaggerated language, nor does it employ emotionally charged words to attract attention.
#
# **3. Stance**
# * **Output:** Neutral
# * **Confidence:** 75%
# * **Reasoning:** The article presents information from both the U.S. (optimism, peace plan revisions) and Russia (Putin's hardline stance, claims of captured cities), as well as Ukraine's diplomatic efforts. It reports on these developments without explicitly favoring one side or expressing a strong opinion. The model's "deny" stance seems to be an anomaly here, as the article is reporting on events rather than denying a specific claim. Based on the human examples, a neutral stance is more appropriate for this type of reporting.
#
# **4. Title vs. Body**
# * **Output:** Agree
# * **Confidence:** 90%
# * **Reasoning:** The title states that the White House is "very optimistic" ahead of a meeting between Putin and Witkoff. The body of the article elaborates on this optimism, detailing the U.S. efforts, the meeting's context, and the ongoing diplomatic discussions, directly aligning with the title's premise.
#
# **5. Context Veracity**
# * **Output:** Misleading
# * **Confidence:** 50%
# * **Reasoning:**
#     *   **Internal:** The article is internally consistent in its narrative.
#     *   **External:**
#         *   `serpapi_search` confirms that Steve Witkoff met with Vladimir Putin in Moscow on a Tuesday, and Jared Kushner was involved.
#         *   `serpapi_search` confirms Karoline Leavitt is the White House Press Secretary.
#         *   `serpapi_search` confirms Putin's statements about Ukraine withdrawing from territories and calling negotiations "pointless," as well as his claims (without evidence) of capturing two Ukrainian cities.
#         *   `serpapi_search` confirms Zelenskyy met Macron in Paris.
#         *   However, `serpapi_search` did **not** find any evidence of "Secretary of State Marco Rubio" being involved in these specific discussions, nor did it confirm Zelenskyy's travel to Dublin for additional diplomatic talks. The inclusion of Marco Rubio as Secretary of State and Zelenskyy's Dublin trip, without external verification, makes the article misleading in these specific details.
#
# **6. Location / Geography**
# * **Output:** Specific
# * **Confidence:** 90%
# * **Reasoning:** The article is primarily focused on specific locations related to the diplomatic efforts and the conflict, including Moscow (for the meeting), Florida (for U.S.-Ukrainian discussions), Paris (for Zelenskyy-Macron meeting), and mentions of Ukraine and its contested cities. The initial dateline is London, but the content is about events in other specific locations.
# --------------------------------------------------------------------------------
#
# [Tool Call] serpapi_search called with query: 'current US Secretary of State'
#
# [Tool Call] serpapi_search called with query: 'current White House Press Secretary'
#
# [Tool Call] serpapi_search called with query: 'Steve Witkoff special envoy Russia Ukraine'
#
# [Tool Call] serpapi_search called with query: 'Jared Kushner Marco Rubio Ukraine peace talks'
#
# [Tool Call] serpapi_search called with query: 'Putin demands Ukraine withdraw territories negotiations pointless'
#
# [Tool Call] serpapi_search called with query: 'Putin claims Russian forces captured two Ukrainian cities'
#
# [Tool Call] serpapi_search called with query: 'Zelenskyy met Macron Paris Dublin diplomatic talks'
#
# [Tool Call] serpapi_search called with query: 'US Ukrainian officials Florida peace plan Trump administration'
# ## Phase 1: Model Predictions
#
# *   news_topic: foreign-policy
# *   intent: inform
# *   sensationalism: neutral
# *   sentiment: Positive
# *   reputation: low
# *   stance: deny
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# *   **Output:** Foreign Policy
# *   **Confidence:** 95%
# *   **Reasoning:** The article exclusively focuses on international diplomatic efforts, peace negotiations between the US, Ukraine, and Russia, and the statements of world leaders regarding the conflict. This clearly falls under the domain of foreign policy.
#
# **2. Sensationalism**
# *   **Output:** Neutral
# *   **Confidence:** 90%
# *   **Reasoning:** The article uses straightforward, factual language to report on diplomatic events. While the subject matter is serious, there is no use of overly dramatic, exaggerated, or emotionally charged words or phrases. The tone is objective and informative.
#
# **3. Stance**
# *   **Output:** Neutral
# *   **Confidence:** 75%
# *   **Reasoning:** The article reports on the perspectives of all parties involved (US optimism, Putin's hardline stance, Zelenskyy's diplomacy) without explicitly favoring one side or expressing a strong opinion. It presents the different positions as reported facts. The model's "deny" stance seems to be an anomaly here, as the text itself is neutral. Based on the calibration examples, a text that presents multiple viewpoints without taking a side should be labeled as neutral.
#
# **4. Title vs. Body**
# *   **Output:** Agree
# *   **Confidence:** 95%
# *   **Reasoning:** The title, "As Putin and Witkoff prepare to meet, White House is 'very optimistic'," directly reflects the central theme of the article's body, which details the upcoming meeting, the White House's optimistic outlook, and the broader diplomatic context. The body elaborates on all aspects mentioned in the title.
#
# **5. Context Veracity**
# *   **Output:** Accurate
# *   **Confidence:** 90%
# *   **Reasoning:**
#     *   **Internal:** The article maintains a consistent narrative and does not present any internal contradictions.
#     *   **External:** Search results confirm several key claims:
#         *   Marco Rubio is indeed the US Secretary of State as of January 21, 2025.
#         *   Karoline Leavitt is the White House Press Secretary as of 2025.
#         *   Steve Witkoff is a US special envoy who recently met with Vladimir Putin in Moscow, accompanied by Jared Kushner, to discuss a peace plan for Ukraine.
#         *   Discussions between US and Ukrainian officials regarding a revised peace plan (originally from the Trump administration) recently took place in Florida.
#         *   Putin has recently reiterated demands for Ukraine to withdraw from claimed territories and called negotiations with Zelenskyy "pointless."
#         *   Russia (and Putin) recently claimed the capture of Ukrainian cities like Pokrovsk and Vovchansk.
#         *   Zelenskyy recently met with French President Emmanuel Macron in Paris. While direct confirmation of travel to Dublin wasn't found in the snippets, the other details are strongly corroborated, suggesting the article is reporting on very recent, accurate events.
#
# **6. Location / Geography**
# *   **Output:** Specific
# *   **Confidence:** 95%
# *   **Reasoning:** The article is primarily focused on specific international locations relevant to the Ukraine war and diplomatic efforts. Key locations mentioned and verified include Moscow (Russia), Florida (USA), Paris (France), Dublin (Ireland), and specific Ukrainian cities (Pokrovsk, Vovchansk). The events are geographically precise and central to the narrative.
# --------------------------------------------------------------------------------
#
# === ARTICLE: 'HBO Max just messed up 'Mad Men' and it makes me sick' ===
#
# >>> Running mode: cot_google
#
# [Tool Call] serpapi_search called with query: 'Mad Men HBO Max 4K puke hose error'
#
# [Tool Call] serpapi_search called with query: 'Mad Men HBO Max 4K remaster Lionsgate wrong file People Magazine corrected episodes'
# ## Phase 1: Model Predictions
#
# ...
#
# [Tool Call] serpapi_search called with query: 'proposal 'healing tsar' reunite Britain Brexit'
#
# [Tool Call] serpapi_search called with query: 'working group 'healing tsar' UK institutions Brexit'
#
# [Tool Call] serpapi_search called with query: 'Prince Charles 'healing tsar' Brexit'
#
# [Tool Call] serpapi_search called with query: 'Thenford House Michael Heseltine 'healing tsar' Brexit'
#
# [Tool Call] serpapi_search called with query: 'Liberal Democrats Bob Geldof 'healing tsar' Brexit'
#
# [Tool Call] serpapi_search called with query: 'Labour Chumbawamba Alice Nutter 'healing tsar' Brexit'
#
# [Tool Call] serpapi_search called with query: 'Conservatives David Van Day 'healing tsar' Brexit'
#
# [Tool Call] serpapi_search called with query: ''It’s a Knockout' MPs 'healing tsar' Brexit'
#
# [Tool Call] serpapi_search called with query: 'DUP 'Great Britain and Northern Ireland' festival 'healing tsar' Brexit'
#
# [Tool Call] serpapi_search called with query: ''healing tsar' Glastonbury Healing Field'
# ## Phase 1: Model Predictions
#
# *   **news_topic**: military
# *   **intent**: inform
# *   **sensationalism**: neutral
# *   **sentiment**: Positive
# *   **reputation**: high
# *   **stance**: deny
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# *   **Output**: Politics / Social Issues
# *   **Confidence**: 95%
# *   **Reasoning**: The article discusses a proposal aimed at addressing social divisions in Britain following Brexit, involving political figures, parties, and cultural initiatives. This clearly falls under the domain of UK politics and social issues.
#
# **2. Sensationalism**
# *   **Output**: Neutral
# *   **Confidence**: 90%
# *   **Reasoning**: Despite the unusual nature of some of the proposals, the article presents the information in a straightforward, descriptive manner without using exaggerated language or emotional appeals.
#
# **3. Stance**
# *   **Output**: Neutral
# *   **Confidence**: 85%
# *   **Reasoning**: The article reports on the proposed 'healing tsar' initiative and the various suggestions and political interests involved without expressing a clear bias for or against the idea. It maintains an objective reporting tone.
#
# **4. Title vs. Body**
# *   **Output**: Agree
# *   **Confidence**: 95%
# *   **Reasoning**: The title, "Proposal for 'healing tsar' to reunite Britain after Brexit," accurately reflects the core subject of the article, which details the origins, proposed role, and specific ideas related to this initiative.
#
# **5. Context Veracity (Cite your search results here)**
# *   **Output**: Inaccurate
# *   **Confidence**: 100%
# *   **Reasoning**:
#     *   **Internal**: Several claims within the article, such as a 12-hour live TV revival of 'It’s a Knockout' with MPs competing, or specific political parties advocating for pop stars as a 'healing tsar', are highly improbable and suggest a lack of factual basis.
#     *   **External**: SerpAPI search results confirm that the article, published by The Guardian on April 1, 2019, was an April Fool's joke. Multiple search snippets explicitly identify the "healing tsar" proposal and its associated details as part of "April Fools' Day news stories 2019."
#
# **6. Location / Geography (Cite your search results here)**
# *   **Output**: Specific (United Kingdom)
# *   **Confidence**: 100%
# *   **Reasoning**: The article is entirely focused on the United Kingdom, discussing the aftermath of Brexit, UK political parties, and specific British locations like Thenford House and Glastonbury.
# --------------------------------------------------------------------------------
#
# [Tool Call] serpapi_search called with query: 'UK 'healing tsar' after Brexit proposal working group'
#
# [Tool Call] serpapi_search called with query: 'Prince Charles 'healing tsar' Brexit'
#
# [Tool Call] serpapi_search called with query: 'Bob Geldof Alice Nutter David Van Day 'healing tsar' Brexit 'It's a Knockout' MPs Glastonbury'
# ## Phase 1: Model Predictions
#
# *   **news_topic**: military
# *   **intent**: inform
# *   **sensationalism**: neutral
# *   **sentiment**: Positive
# *   **reputation**: high
# *   **stance**: deny
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# *   **Output**: Politics / Social Issues
# *   **Confidence**: 95%
# *   **Reasoning**: The article discusses a proposal for national reconciliation and social cohesion in Britain following Brexit, involving political figures and cultural events. This clearly falls under politics and social issues, not military.
#
# **2. Sensationalism**
# *   **Output**: Neutral
# *   **Confidence**: 80%
# *   **Reasoning**: While the *content* of the article is highly improbable and borders on absurd (e.g., "It's a Knockout" with MPs, specific pop stars as tsars), the *language* used to describe these proposals is presented in a relatively straightforward, journalistic tone without excessive emotional appeals or dramatic phrasing.
#
# **3. Stance**
# *   **Output**: Neutral
# *   **Confidence**: 70%
# *   **Reasoning**: The article presents the proposal and various viewpoints on it without explicitly endorsing or condemning it. While the model predicted "deny," the article's tone is more descriptive of the (fictional) proposal rather than taking a clear stance against it. Given the satirical nature, the "deny" might be an interpretation of the inherent absurdity, but from a surface reading, it's presented neutrally.
#
# **4. Title vs. Body**
# *   **Output**: Agree
# *   **Confidence**: 95%
# *   **Reasoning**: The title "Proposal for 'healing tsar' to reunite Britain after Brexit" accurately reflects the central theme and content discussed throughout the body of the article, which elaborates on this proposal, its potential figures, and associated events.
#
# **5. Context Veracity**
# *   **Output**: Inaccurate
# *   **Confidence**: 100%
# *   **Reasoning**:
#     *   **Internal**: The claims within the article, such as specific pop stars being advocated for a "healing tsar" role by political parties, a 12-hour "It's a Knockout" revival with MPs, and a tsar debuting at Glastonbury's Healing Field, are highly improbable and lack any grounding in reality.
#     *   **External**: `serpapi_search` for "UK 'healing tsar' after Brexit proposal working group", "Prince Charles 'healing tsar' Brexit", and "Bob Geldof Alice Nutter David Van Day 'healing tsar' Brexit 'It's a Knockout' MPs Glastonbury" consistently returned the original Guardian article from April 1, 2019, as the primary or only source for these claims. The publication date strongly indicates the article is an April Fool's joke or satire, meaning its claims are fabricated.
#
# **6. Location / Geography**
# *   **Output**: Specific (United Kingdom)
# *   **Confidence**: 100%
# *   **Reasoning**: The article explicitly discusses the reunification of "Britain after Brexit," mentions "major UK institutions," "Prince Charles," "Thenford House" (Michael Heseltine's estate in the UK), "Liberal Democrats," "Labour," "Conservatives," "DUP," and "Glastonbury," all of which are specific to the United Kingdom.
# --------------------------------------------------------------------------------
#
# === ARTICLE: 'You won’t read this life-changing study about clickbait headlines' ===
#
# >>> Running mode: cot_google
#
# [Tool Call] serpapi_search called with query: 'Penn State University study clickbait headlines effectiveness'
# ## Phase 1: Model Predictions
# - news_topic: florida
# - intent: Inform
# - sensationalism: Neutral
# - sentiment: Positive
# - reputation: Medium
# - stance: Neutral
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# * **Output:** Media / Research
# * **Confidence:** 95%
# * **Reasoning:** The article discusses academic research on media consumption patterns, specifically regarding headline effectiveness and its implications for misinformation and AI.
#
# **2. Sensationalism**
# * **Output:** Neutral
# * **Confidence:** 85%
# * **Reasoning:** While the title uses a playful, self-referential clickbait style, the body of the article presents the research findings in a factual and academic tone, without exaggeration or overly dramatic language.
#
# **3. Stance**
# * **Output:** Neutral
# * **Confidence:** 90%
# * **Reasoning:** The article objectively reports on the findings of a research study, presenting the results and their implications without expressing a particular bias or opinion for or against clickbait.
#
# **4. Title vs. Body**
# * **Output:** Discuss
# * **Confidence:** 90%
# * **Reasoning:** The title, "You won’t read this life-changing study about clickbait headlines," is a meta-commentary that uses a clickbait-like structure to introduce an article *about* clickbait. The body then proceeds to detail the study's findings on clickbait, directly discussing the subject hinted at in the title.
#
# **5. Context Veracity (Cite your search results here)**
# * **Output:** Accurate
# * **Confidence:** 95%
# * **Reasoning:**
#     * **Internal:** The article presents a coherent and logical account of the study's methodology and findings.
#     * **External:** SerpAPI search results confirm the existence of a Penn State University study on clickbait headlines, with snippets directly stating that "clickbait often did not perform any better and, in some cases, performed worse than traditional headlines," and that "AI tools used to classify clickbait reached only 47% agreement," aligning with the article's claims.
#         * `https://www.psu.edu/news/research/story/clickbait-headlines-might-not-lure-readers-much-may-confuse-ai`
#         * `https://pike.psu.edu/publications/chi21.pdf`
#
# **6. Location / Geography (Cite your search results here)**
# * **Output:** United States
# * **Confidence:** 95%
# * **Reasoning:** The article explicitly mentions "Penn State University," which is located in the United States. The research itself has global implications for understanding media and misinformation, but the origin of the study is specific to a US institution.
# --------------------------------------------------------------------------------
#
# [Warning] Rate limit hit. Retrying in 20s...
#
# [Tool Call] serpapi_search called with query: 'Penn State University study clickbait headlines effectiveness'
# ## Phase 1: Model Predictions
# - **news_topic**: florida
# - **intent**: Inform
# - **sensationalism**: Neutral
# - **sentiment**: Positive
# - **reputation**: Medium
# - **stance**: Neutral
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# * **Output**: Media / Research
# * **Confidence**: 95%
# * **Reasoning**: The article focuses on a research study about clickbait headlines, their impact on engagement, and challenges in AI detection, which are topics related to media, communication, and academic research.
#
# **2. Sensationalism**
# * **Output**: Neutral
# * **Confidence**: 80%
# * **Reasoning**: While the title employs a clickbait-like phrase ("life-changing"), the article's body presents research findings in a straightforward, factual, and analytical manner, discussing the study's results without exaggeration or overly dramatic language.
#
# **3. Stance**
# * **Output**: Neutral
# * **Confidence**: 90%
# * **Reasoning**: The article objectively reports on the findings of a Penn State University study regarding the effectiveness of clickbait headlines. It presents the research and its implications without expressing a strong opinion or bias for or against clickbait.
#
# **4. Title vs. Body**
# * **Output**: Discuss
# * **Confidence**: 85%
# * **Reasoning**: The title, "You won’t read this life-changing study about clickbait headlines," is a meta-commentary that uses a clickbait-esque phrase to introduce an article about a study that found clickbait to be ineffective. It directly relates to and discusses the content of the body in an ironic and self-referential way.
#
# **5. Context Veracity**
# * **Output**: Accurate
# * **Confidence**: 95%
# * **Reasoning**:
#     * **Internal**: The article's claims about the Penn State study are consistent within the text.
#     * **External**: A search for "Penn State University study clickbait headlines effectiveness" yielded direct evidence from psu.edu (https://www.psu.edu/news/research/story/clickbait-headlines-might-not-lure-readers-much-may-confuse-ai) confirming the existence and findings of a study that concluded: "A team of researchers found that clickbait often did not perform any better and, in some cases, performed worse than traditional headlines."
#
# **6. Location / Geography**
# * **Output**: United States / Global
# * **Confidence**: 90%
# * **Reasoning**: The research originates from Penn State University, located in the United States. However, the topic of clickbait headlines, their effectiveness, and implications for misinformation are relevant to online media consumption and communication globally.
# --------------------------------------------------------------------------------
#
# [Tool Call] serpapi_search called with query: 'Penn State University study clickbait headlines effectiveness'
# ## Phase 1: Model Predictions
# - news_topic: florida
# - intent: inform
# - sensationalism: neutral
# - sentiment: Positive
# - reputation: medium
# - stance: neutral
#
# ## Phase 2: Qualitative Analysis
#
# **1. News Topic**
# * **Output:** Media / Technology / Research
# * **Confidence:** 95%
# * **Reasoning:** The article focuses on academic research concerning clickbait headlines, their effectiveness, and implications for misinformation and AI detection. This clearly falls under the categories of media studies, technology, and academic research.
#
# **2. Sensationalism**
# * **Output:** Neutral
# * **Confidence:** 90%
# * **Reasoning:** The article presents the findings of a research study in a factual and objective manner. While the title is a playful example of a clickbait-style headline, the body of the text avoids exaggerated claims or dramatic language, maintaining a neutral tone.
#
# **3. Stance**
# * **Output:** Neutral
# * **Confidence:** 95%
# * **Reasoning:** The article's primary purpose is to report on the findings of a Penn State University study. It objectively presents the research, its methodology, and its conclusions without expressing a biased opinion for or against clickbait.
#
# **4. Title vs. Body**
# * **Output:** Discuss
# * **Confidence:** 95%
# * **Reasoning:** The title, "You won’t read this life-changing study about clickbait headlines," is a self-referential example of a clickbait headline. The body of the article then proceeds to discuss a study about the effectiveness of clickbait headlines, directly engaging with the concept presented in the title.
#
# **5. Context Veracity**
# * **Output:** Accurate
# * **Confidence:** 95%
# * **Reasoning:**
#     *   **Internal:** The article maintains internal consistency, presenting the study's premise, methodology, and results in a coherent narrative.
#     *   **External:** A `serpapi_search` for "Penn State University study clickbait headlines effectiveness" yielded multiple results, including a Penn State news release from June 2021 titled "Clickbait headlines might not lure readers as much, may confuse AI" and a Fast Company article (the source of this input) with a similar title. These results confirm the existence and findings of the Penn State study as described in the article, which found that clickbait headlines often did not perform better and sometimes performed worse than traditional headlines.
#
# **6. Location / Geography**
# * **Output:** United States
# * **Confidence:** 90%
# * **Reasoning:** The article explicitly mentions "Penn State University," which is located in the United States. While the topic of clickbait and its implications are global, the specific research cited originates from a U.S. institution.
# --------------------------------------------------------------------------------
#
# === ARTICLE: 'Winds, warmth and relentless drought fueled Los Angeles fires, scientists say' ===
#
# >>> Running mode: cot_google
#
# [Tool Call] serpapi_search called with query: 'California fire risk year-round'
#
# [Tool Call] serpapi_search called with query: 'Kimberley Simpson University of Sheffield climate change wildfire'
#
# [Warning] Rate limit hit. Retrying in 20s...
#
# [Warning] Rate limit hit. Retrying in 40s...
