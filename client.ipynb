# %%
from google.adk.agents.remote_a2a_agent import RemoteA2aAgent
from google.adk.runners import InMemoryRunner

# %%
YOUR_IP = "100.117.24.250"  
AGENT_CARD_URL = f"http://{YOUR_IP}:8000/.well-known/agent-card.json"

remote_coordinator = RemoteA2aAgent(
    name="NetworkCoordinator",
    agent_card=AGENT_CARD_URL
)

print("🔗 Connected to the Root Agent on the network!")
# Out:
# 🔗 Connected to the Root Agent on the network!
# /var/folders/lq/92c4q9fj4dz0frz0wjdlq2lr0000gn/T/ipykernel_38712/3576537504.py:4: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subjected to breaking changes. A2A protocol and SDK arethemselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   remote_coordinator = RemoteA2aAgent(

# %%
article_body = "HONG KONG, Dec 2 (Reuters) - Hong Kong's leader said on Tuesday a judge-led committee will investigate the cause of the city's deadliest fire in decades and review government oversight of renovation practices linked to the blaze that killed at least 151 people.\nPolice have arrested 13 people for suspected manslaughter, and 12 others in a related corruption probe. Officials said substandard plastic mesh and insulation foam used during renovation works fueled the rapid spread of the fire across seven high-rise towers.\nAuthorities said they aim to avoid similar tragedies by examining how the fire spread so quickly and the oversight failures around building renovations.\n\nSEARCH AND INVESTIGATION\nInvestigators have combed most of the damaged towers, finding victims in stairwells and rooftops as they attempted to escape. Around 30 people remain missing.\nSome civic groups have demanded transparency and accountability, while police have warned against \"politicising\" the tragedy. A student was detained and later released, and media reports indicate others are under investigation for possible sedition.\nInternational rights groups argue the government's response reflects broader suppression of criticism.\n\nRESIDENTS WARNED PRIOR\nResidents of Wang Fuk Court had previously raised concerns about fire hazards and flammable materials used on scaffolding. Tests showed mesh samples did not meet fire-retardant standards.\nOfficials also reported foam insulation accelerated the fire and that alarms were malfunctioning.\nOver 1,500 residents have been displaced into temporary housing. Authorities are offering emergency funds and fast-tracked document replacement.\n\nVIGILS AND RECOVERY\nThousands across Hong Kong and cities like Tokyo, Taipei, and London have held vigils. Several victims were migrant domestic workers.\nThe search of the most heavily damaged towers may take weeks, as responders work through collapsed interiors."
article_title = "Hong Kong orders judge-led probe into fire that killed 151"
prompt = f"Title: {article_title}\nBody: {article_body}"

# %%
runner = InMemoryRunner(agent=remote_coordinator)

prompt = f"Title: {article_title}\nBody: {article_body}"

response = await runner.run_debug(prompt)
# Out:
#  ### Created new session: debug_session_id
#
# User > Title: Hong Kong orders judge-led probe into fire that killed 151
# Body: HONG KONG, Dec 2 (Reuters) - Hong Kong's leader said on Tuesday a judge-led committee will investigate the cause of the city's deadliest fire in decades and review government oversight of renovation practices linked to the blaze that killed at least 151 people.
# Police have arrested 13 people for suspected manslaughter, and 12 others in a related corruption probe. Officials said substandard plastic mesh and insulation foam used during renovation works fueled the rapid spread of the fire across seven high-rise towers.
# Authorities said they aim to avoid similar tragedies by examining how the fire spread so quickly and the oversight failures around building renovations.
#
# SEARCH AND INVESTIGATION
# Investigators have combed most of the damaged towers, finding victims in stairwells and rooftops as they attempted to escape. Around 30 people remain missing.
# Some civic groups have demanded transparency and accountability, while police have warned against "politicising" the tragedy. A student was detained and later released, and media reports indicate others are under investigation for possible sedition.
# International rights groups argue the government's response reflects broader suppression of criticism.
#
# RESIDENTS WARNED PRIOR
# Residents of Wang Fuk Court had previously raised concerns about fire hazards and flammable materials used on scaffolding. Tests showed mesh samples did not meet fire-retardant standards.
# Officials also reported foam insulation accelerated the fire and that alarms were malfunctioning.
# Over 1,500 residents have been displaced into temporary housing. Authorities are offering emergency funds and fast-tracked document replacement.
#
# VIGILS AND RECOVERY
# Thousands across Hong Kong and cities like Tokyo, Taipei, and London have held vigils. Several victims were migrant domestic workers.
# The search of the most heavily damaged towers may take weeks, as responders work through collapsed interiors.
# /opt/miniconda3/lib/python3.12/site-packages/google/adk/agents/remote_a2a_agent.py:399: UserWarning: [EXPERIMENTAL] convert_genai_part_to_a2a_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subjected to breaking changes. A2A protocol and SDK arethemselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   converted_parts = self._genai_part_converter(part)
# NetworkCoordinator > ## 🧠 Agent Analysis Summary
#
# ### 🔍 Labels
# | Signal | Label | Confidence |
# |---|---|---|
# | News Coverage | Disasters and Accidents | 95% |
# | Intent | Inform | 95% |
# | Sensationalism | neutral | 75% |
# | Stance | neutral | 60% |
# | Title vs Body | Agree | 100% |
# | Context Veracity | Accurate | 95% |
#
# ### ✅ Double-check
# - The intent to inform aligns with the neutral sensationalism and the factual reporting of the fire. The title and body agree, and the context is deemed accurate. The stance is neutral, reflecting the reporting of both official actions and public/rights group concerns.
#
# ### 🧾 Short Summary
# Hong Kong is launching a judge-led investigation into a deadly fire that killed at least 151 people, with a review of renovation practices and government oversight. The fire was exacerbated by substandard materials, leading to arrests and ongoing investigations into manslaughter and corruption. The event has displaced over 1,500 residents and prompted vigils and calls for accountability.
#
# ### 🎯 Final Judgment
#
# **CONFIDENCE SCORE RUBRIC (0–100%):**
# * **90–100%:** Explicit, unambiguous language supports your label.
# * **75–89%:** Trend is clear and consistent.
# * **50–74%:** Text is mixed, ambiguous, or open to interpretation.
# * **25–49%:** Text is too short or vague.
# * **0–24%:** Cannot meaningfully determine.
#
# - **Final Labels for News Coverage:** Disasters and Accidents
# - **Final Confidence:** 95%
# - **Why (1 bullet):**
#   - The article exclusively details a significant fire incident, its causes, and the subsequent investigation, clearly falling under the "Disasters and Accidents" category.
#
# - **Final Labels for Intent:** Inform
# - **Final Confidence:** 95%
# - **Why (1 bullet):**
#   - The article's primary goal is to convey factual information about the fire, the investigation, and its consequences, using a neutral tone and citing a news source.
#
# - **Final Labels for Sensationalism:** Neutral
# - **Final Confidence:** 75%
# - **Why (1 bullet):**
#   - While the event is tragic, the article maintains a factual and objective tone, focusing on reporting official actions and details rather than using inflammatory language.
#
# - **Final Labels for Stance:** Neutral
# - **Final Confidence:** 60%
# - **Why (1 bullet):**
#   - The article presents information factually, including details about the investigation and government responses, while also acknowledging concerns raised by civic groups and international rights organizations, resulting in a balanced, neutral stance.
#
# - **Final Labels for Title vs Body:** Agree
# - **Final Confidence:** 100%
# - **Why (1 bullet):**
#   - The headline accurately summarizes the main point of the article, which is the initiation of a judge-led probe into the fire and the review of renovation practices.
#
# - **Final Labels for Context Veracity:** Accurate
# - **Final Confidence:** 95%
# - **Why (1 bullet):**
#   - The information presented is coherent, plausible, and consistent with the reporting of such an event, with details that lend credibility to its accuracy.
# /opt/miniconda3/lib/python3.12/site-packages/google/adk/a2a/converters/event_converter.py:245: UserWarning: [EXPERIMENTAL] convert_a2a_message_to_event: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subjected to breaking changes. A2A protocol and SDK arethemselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   return convert_a2a_message_to_event(
# /opt/miniconda3/lib/python3.12/site-packages/google/adk/a2a/converters/event_converter.py:315: UserWarning: [EXPERIMENTAL] convert_a2a_part_to_genai_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subjected to breaking changes. A2A protocol and SDK arethemselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   parts = part_converter(a2a_part)
